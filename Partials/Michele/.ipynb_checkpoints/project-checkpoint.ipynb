# %%
import pandas as pd
import json
import numpy as np

# %%
data2016 = json.load(open('condensed_2017.json'))

# %% [markdown]
# What does the dataset look like ? The dataset is a collection of json files, 1 for each year. The file for 2017
# is currently being update on an hourly basis. In each json file, there is an array where each element represents
# a seperate tweet. In each array element, the following information can be found:<br>
#
# <b>created_at:</b> the date the tweet was posted<br>
# favourite_count: the number of individual users that liked this post<br>
# id_str: an id for this tweet<br>
# in_reply_to_user_id_str: the id of a tweet that this tweet is a reply to<br>
# in_retweet: <br>
# retweet_count: the amount of times this tweet was retweeted<br>
# source: which device it was posted from (desktop/phone)<br>
# text: the actual text from this tweet<br>

# %%
#Dataframe containing all tweets from 2016
df = pd.DataFrame(data2016)
df.rename(columns={"id_str":"id","created_at":"date","favourite_count":"likes","in_reply_to_user_id_str":"reply_id"},inplace=True)
df = df.set_index("id")

# %%
df
# Out:
#                                               date  favorite_count  reply_id  \
# id
# 935152378747195392  Mon Nov 27 14:24:36 +0000 2017           39685      None
# 935150368207654912  Mon Nov 27 14:16:36 +0000 2017           30766      None
# 935147410472480769  Mon Nov 27 14:04:51 +0000 2017           82892      None
# 934961858380955648  Mon Nov 27 01:47:32 +0000 2017           70471      None
# 934896989539586054  Sun Nov 26 21:29:46 +0000 2017          133875      None
# 934792302341521408  Sun Nov 26 14:33:47 +0000 2017           70295      None
# 934781939088629761  Sun Nov 26 13:52:36 +0000 2017           92822      None
# 934563828834164739  Sat Nov 25 23:25:54 +0000 2017           63753      None
# 934551607596986368  Sat Nov 25 22:37:21 +0000 2017          107952      None
# 934542257222451206  Sat Nov 25 22:00:11 +0000 2017           41394      None
# 934539256940417024  Sat Nov 25 21:48:16 +0000 2017           66188      None
# 934507210385829888  Sat Nov 25 19:40:55 +0000 2017           48664      None
# 934189999045693441  Fri Nov 24 22:40:26 +0000 2017          162373      None
# 934131805409697792  Fri Nov 24 18:49:12 +0000 2017           99711      None
# 934080974773776384  Fri Nov 24 15:27:13 +0000 2017          141854      None
# 934031535757582336  Fri Nov 24 12:10:46 +0000 2017           90264      None
# 934029886842458112  Fri Nov 24 12:04:13 +0000 2017           67489      None
# 934026050388013056  Fri Nov 24 11:48:58 +0000 2017           59039      None
# 933921775984967681  Fri Nov 24 04:54:37 +0000 2017           67383      None
# 933918671503753216  Fri Nov 24 04:42:17 +0000 2017           64218      None
# 933917690552573952  Fri Nov 24 04:38:23 +0000 2017               0      None
# 933917415028772864  Fri Nov 24 04:37:17 +0000 2017               0      None
# 933837062293291008  Thu Nov 23 23:18:00 +0000 2017           88427      None
# 933831194558582784  Thu Nov 23 22:54:41 +0000 2017           56212      None
# 933720598383026176  Thu Nov 23 15:35:13 +0000 2017           99669      None
# 933692459351265280  Thu Nov 23 13:43:24 +0000 2017           51508  25073877
# 933662564587855877  Thu Nov 23 11:44:36 +0000 2017          146759      None
# 933659179348299776  Thu Nov 23 11:31:09 +0000 2017            9698  20508720
# 933658521828315136  Thu Nov 23 11:28:32 +0000 2017          205837      None
# 933517194142584833  Thu Nov 23 02:06:57 +0000 2017           50901      None
# ...                                            ...             ...       ...
# 816644321768312832  Wed Jan 04 13:55:53 +0000 2017           46212      None
# 816638194468999169  Wed Jan 04 13:31:32 +0000 2017           46561      None
# 816637064708030464  Wed Jan 04 13:27:03 +0000 2017           42611      None
# 816635078067490816  Wed Jan 04 13:19:09 +0000 2017           86542      None
# 816632793862176769  Wed Jan 04 13:10:05 +0000 2017           42047      None
# 816620855958601730  Wed Jan 04 12:22:38 +0000 2017           61018      None
# 816452807024840704  Wed Jan 04 01:14:52 +0000 2017           80009      None
# 816433590892429312  Tue Jan 03 23:58:31 +0000 2017           57750      None
# 816354639859871745  Tue Jan 03 18:44:47 +0000 2017           53127      None
# 816333480409833472  Tue Jan 03 17:20:43 +0000 2017           82862      None
# 816328314759606272  Tue Jan 03 17:00:11 +0000 2017           54691      None
# 816324295781740544  Tue Jan 03 16:44:13 +0000 2017           52850      None
# 816300003442495488  Tue Jan 03 15:07:41 +0000 2017           42800      None
# 816298944456232960  Tue Jan 03 15:03:29 +0000 2017           43062      None
# 816265668958031872  Tue Jan 03 12:51:15 +0000 2017           53372      None
# 816264484629184513  Tue Jan 03 12:46:33 +0000 2017           58809      None
# 816260343391514624  Tue Jan 03 12:30:05 +0000 2017           73104      None
# 816068355555815424  Mon Jan 02 23:47:12 +0000 2017           64480      None
# 816057920223846400  Mon Jan 02 23:05:44 +0000 2017           92256      None
# 815992069412057088  Mon Jan 02 18:44:04 +0000 2017           62670      None
# 815990335318982656  Mon Jan 02 18:37:10 +0000 2017           47285      None
# 815989154555297792  Mon Jan 02 18:32:29 +0000 2017           13862    759251
# 815973752785793024  Mon Jan 02 17:31:17 +0000 2017           63340      None
# 815930688889352192  Mon Jan 02 14:40:10 +0000 2017          124024      None
# 815449933453127681  Sun Jan 01 06:49:49 +0000 2017               0      None
# 815449868739211265  Sun Jan 01 06:49:33 +0000 2017               0      None
# 815433444591304704  Sun Jan 01 05:44:17 +0000 2017               0      None
# 815433217595547648  Sun Jan 01 05:43:23 +0000 2017               0      None
# 815432169464197121  Sun Jan 01 05:39:13 +0000 2017               0      None
# 815422340540547073  Sun Jan 01 05:00:10 +0000 2017          126230      None
#
#                     is_retweet  retweet_count               source  \
# id
# 935152378747195392       False           8437   Twitter for iPhone
# 935150368207654912       False           7176   Twitter for iPhone
# 935147410472480769       False          23496   Twitter for iPhone
# 934961858380955648       False          14581   Twitter for iPhone
# 934896989539586054       False          30416   Twitter for iPhone
# 934792302341521408       False          16170   Twitter for iPhone
# 934781939088629761       False          24388   Twitter for iPhone
# 934563828834164739       False          18789   Twitter for iPhone
# 934551607596986368       False          32367   Twitter for iPhone
# 934542257222451206       False           9692   Twitter for iPhone
# 934539256940417024       False          14346   Twitter for iPhone
# 934507210385829888       False          10907   Twitter for iPhone
# 934189999045693441       False          43460   Twitter for iPhone
# 934131805409697792       False          20792   Twitter for iPhone
# 934080974773776384       False          33444   Twitter for iPhone
# 934031535757582336       False          15407   Twitter for iPhone
# 934029886842458112       False          15964   Twitter for iPhone
# 934026050388013056       False          15022   Twitter for iPhone
# 933921775984967681       False          15023   Twitter for iPhone
# 933918671503753216       False          12073   Twitter for iPhone
# 933917690552573952        True           7455   Twitter for iPhone
# 933917415028772864        True           6882   Twitter for iPhone
# 933837062293291008       False          18708   Twitter for iPhone
# 933831194558582784       False          11032     Twitter for iPad
# 933720598383026176       False          24547         Media Studio
# 933692459351265280       False           8557   Twitter for iPhone
# 933662564587855877       False          37143   Twitter for iPhone
# 933659179348299776       False           4083   Twitter for iPhone
# 933658521828315136       False          44285   Twitter for iPhone
# 933517194142584833       False          10344   Twitter for iPhone
# ...                        ...            ...                  ...
# 816644321768312832       False          11128  Twitter for Android
# 816638194468999169       False          10731  Twitter for Android
# 816637064708030464       False          10260  Twitter for Android
# 816635078067490816       False          19529  Twitter for Android
# 816632793862176769       False          14810  Twitter for Android
# 816620855958601730       False          18118  Twitter for Android
# 816452807024840704       False          23441  Twitter for Android
# 816433590892429312       False          14678  Twitter for Android
# 816354639859871745       False          14057   Twitter for iPhone
# 816333480409833472       False          20653  Twitter for Android
# 816328314759606272       False          12727   Twitter for iPhone
# 816324295781740544       False          15571   Twitter for iPhone
# 816300003442495488       False           9525  Twitter for Android
# 816298944456232960       False          10851  Twitter for Android
# 816265668958031872       False          12599  Twitter for Android
# 816264484629184513       False          14481  Twitter for Android
# 816260343391514624       False          18864  Twitter for Android
# 816068355555815424       False          17507  Twitter for Android
# 816057920223846400       False          26703  Twitter for Android
# 815992069412057088       False          13437  Twitter for Android
# 815990335318982656       False           9057  Twitter for Android
# 815989154555297792       False           3948  Twitter for Android
# 815973752785793024       False          17411  Twitter for Android
# 815930688889352192       False          29248  Twitter for Android
# 815449933453127681        True          13659   Twitter for iPhone
# 815449868739211265        True           6847   Twitter for iPhone
# 815433444591304704        True           6941   Twitter for iPhone
# 815433217595547648        True           7144   Twitter for iPhone
# 815432169464197121        True           5548   Twitter for iPhone
# 815422340540547073       False          32665   Twitter for iPhone
#
#                                                                  text
# id
# 935152378747195392  The Tax Cut Bill is coming along very well, gr...
# 935150368207654912  The good news is that their ratings are terrib...
# 935147410472480769  We should have a contest as to which of the Ne...
# 934961858380955648  Back in D.C., big week for Tax Cuts and many o...
# 934896989539586054  Since the first day I took office, all you hea...
# 934792302341521408  I endorsed Luther Strange in the Alabama Prima...
# 934781939088629761  The last thing we need in Alabama and the U.S....
# 934563828834164739  Wow, even I didn’t realize we did so much. Wis...
# 934551607596986368  .@FoxNews is MUCH more important in the United...
# 934542257222451206  Check out the recent Editorial in the Wall Str...
# 934539256940417024  The Consumer Financial Protection Bureau, or C...
# 934507210385829888  Happy #SmallBusinessSaturday!\n\nA great day t...
# 934189999045693441  Time Magazine called to say that I was PROBABL...
# 934131805409697792  Will be calling the President of Egypt in a sh...
# 934080974773776384  Horrible and cowardly terrorist attack on inno...
# 934031535757582336  After Turkey call I will be heading over to Tr...
# 934029886842458112  Will be speaking to President Recep Tayyip Erd...
# 934026050388013056  Can you believe that the disrespect for our Co...
# 933921775984967681          Two great people! https://t.co/5cVnMhnmuH
# 933918671503753216  A great guy (with great ratings)! https://t.co...
# 933917690552573952  RT @DeptofDefense: #HappyThanksgiving from @US...
# 933917415028772864  RT @Scavino45: Today, @POTUS @realDonaldTrump ...
# 933837062293291008  ObamaCare premiums are going up, up, up, just ...
# 933831194558582784  My great honor to join our incredible men and ...
# 933720598383026176        HAPPY THANKSGIVING! https://t.co/nQhi7XopMW
# 933692459351265280  Will be doing a live Thanksgiving Video Teleco...
# 933662564587855877                          MAKE AMERICA GREAT AGAIN!
# 933659179348299776           @ThePlumLineGS MAKE AMERICA GREAT AGAIN!
# 933658521828315136  HAPPY THANKSGIVING, your Country is starting t...
# 933517194142584833  ....And it will get even better with Tax Cuts!...
# ...                                                               ...
# 816644321768312832  Republicans must be careful in that the Dems o...
# 816638194468999169  things they did and said (like giving the ques...
# 816637064708030464  Somebody hacked the DNC but why did they not h...
# 816635078067490816  Thank you to Ford for scrapping a new plant in...
# 816632793862176769  "@FoxNews: Julian Assange on U.S. media covera...
# 816620855958601730  Julian Assange said "a 14 year old could have ...
# 816452807024840704  The "Intelligence" briefing on so-called "Russ...
# 816433590892429312  I will be having a general news conference on ...
# 816354639859871745  "Trump is already delivering the jobs he promi...
# 816333480409833472  There should be no further releases from Gitmo...
# 816328314759606272  Instead of driving jobs and wealth away, AMERI...
# 816324295781740544  "@DanScavino: Ford to scrap Mexico plant, inve...
# 816300003442495488  ........may be, their number one act and prior...
# 816298944456232960  With all that Congress has to work on, do they...
# 816265668958031872  The Democrat Governor.of Minnesota said "The A...
# 816264484629184513  People must remember that ObamaCare just doesn...
# 816260343391514624  General Motors is sending Mexican made model o...
# 816068355555815424  China has been taking out massive amounts of m...
# 816057920223846400  North Korea just stated that it is in the fina...
# 815992069412057088  I thought and felt I would win big, easily ove...
# 815990335318982656  Various media outlets and pundits say that I t...
# 815989154555297792  @CNN just released a book called "Unprecedente...
# 815973752785793024  Chicago murder rate is record setting - 4,331 ...
# 815930688889352192  Well, the New Year begins. We will, together, ...
# 815449933453127681  RT @IvankaTrump: 2016 has been one of the most...
# 815449868739211265  RT @DonaldJTrumpJr: Happy new year everyone. #...
# 815433444591304704  RT @EricTrump: 2016 was such an incredible yea...
# 815433217595547648  RT @Reince: Happy New Year + God's blessings t...
# 815432169464197121  RT @DanScavino: On behalf of our next #POTUS &...
# 815422340540547073  TO ALL AMERICANS-\n#HappyNewYear &amp; many bl...
#
# [2353 rows x 7 columns]

# %%
'''
Observations:
reply_id seems to be None for a lot of entries, not sure if it's the case for all of them.
Can be dropped if its always None

Text needs to be cleaned of certain characters

Note that retweet != reply. Retweet means that trump took someone else's tweet and posted it on his page.
Reply means he directly tweets to a tweet someone else made
'''
# Out:
# "\nObservations:\nreply_id seems to be None for a lot of entries, not sure if it's the case for all of them.\nCan be dropped if its always None\n\nText needs to be cleaned of certain characters\n\nNote that retweet != reply. Retweet means that trump took someone else's tweet and posted it on his page.\nReply means he directly tweets to a tweet someone else made\n"

# %%
'''
Text cleaning

In the text we can see that the ampersand symbol & is often encoded as &amp; so we need to replace all occurences of this
We can also remove http links for now as they are not really contributing to a sentiment analysis

We should exctract hashtags as they reveal something important, can put them in a new column where each entry is a list ?

Remove \n characters 
'''

#Given a text t, returns all hashtags as a list
def GetHashtags(t):
    hashtags=[]
    splitText=text.split(" ")
    for s in splitText:
        if("#" in s):
            hashtags.append(s)
    return hashtags

#    i=242
for i in range(len(df)):
    text=df.iloc[i]["text"]
    text=text.replace("&amp;","&")
    text=text.replace("\n;","")
    
    text=" ".join(text.split("\n"))

    text=text.split("https",1)[0]   
    
    
    hashtags=GetHashtags(text)
    df.set_value(i,"text",text)

# %%
df
# Out:
#                                               date  favorite_count  reply_id  \
# id
# 935152378747195392  Mon Nov 27 14:24:36 +0000 2017         39685.0      None
# 935150368207654912  Mon Nov 27 14:16:36 +0000 2017         30766.0      None
# 935147410472480769  Mon Nov 27 14:04:51 +0000 2017         82892.0      None
# 934961858380955648  Mon Nov 27 01:47:32 +0000 2017         70471.0      None
# 934896989539586054  Sun Nov 26 21:29:46 +0000 2017        133875.0      None
# 934792302341521408  Sun Nov 26 14:33:47 +0000 2017         70295.0      None
# 934781939088629761  Sun Nov 26 13:52:36 +0000 2017         92822.0      None
# 934563828834164739  Sat Nov 25 23:25:54 +0000 2017         63753.0      None
# 934551607596986368  Sat Nov 25 22:37:21 +0000 2017        107952.0      None
# 934542257222451206  Sat Nov 25 22:00:11 +0000 2017         41394.0      None
# 934539256940417024  Sat Nov 25 21:48:16 +0000 2017         66188.0      None
# 934507210385829888  Sat Nov 25 19:40:55 +0000 2017         48664.0      None
# 934189999045693441  Fri Nov 24 22:40:26 +0000 2017        162373.0      None
# 934131805409697792  Fri Nov 24 18:49:12 +0000 2017         99711.0      None
# 934080974773776384  Fri Nov 24 15:27:13 +0000 2017        141854.0      None
# 934031535757582336  Fri Nov 24 12:10:46 +0000 2017         90264.0      None
# 934029886842458112  Fri Nov 24 12:04:13 +0000 2017         67489.0      None
# 934026050388013056  Fri Nov 24 11:48:58 +0000 2017         59039.0      None
# 933921775984967681  Fri Nov 24 04:54:37 +0000 2017         67383.0      None
# 933918671503753216  Fri Nov 24 04:42:17 +0000 2017         64218.0      None
# 933917690552573952  Fri Nov 24 04:38:23 +0000 2017             0.0      None
# 933917415028772864  Fri Nov 24 04:37:17 +0000 2017             0.0      None
# 933837062293291008  Thu Nov 23 23:18:00 +0000 2017         88427.0      None
# 933831194558582784  Thu Nov 23 22:54:41 +0000 2017         56212.0      None
# 933720598383026176  Thu Nov 23 15:35:13 +0000 2017         99669.0      None
# 933692459351265280  Thu Nov 23 13:43:24 +0000 2017         51508.0  25073877
# 933662564587855877  Thu Nov 23 11:44:36 +0000 2017        146759.0      None
# 933659179348299776  Thu Nov 23 11:31:09 +0000 2017          9698.0  20508720
# 933658521828315136  Thu Nov 23 11:28:32 +0000 2017        205837.0      None
# 933517194142584833  Thu Nov 23 02:06:57 +0000 2017         50901.0      None
# ...                                            ...             ...       ...
# 2323                                           NaN             NaN       NaN
# 2324                                           NaN             NaN       NaN
# 2325                                           NaN             NaN       NaN
# 2326                                           NaN             NaN       NaN
# 2327                                           NaN             NaN       NaN
# 2328                                           NaN             NaN       NaN
# 2329                                           NaN             NaN       NaN
# 2330                                           NaN             NaN       NaN
# 2331                                           NaN             NaN       NaN
# 2332                                           NaN             NaN       NaN
# 2333                                           NaN             NaN       NaN
# 2334                                           NaN             NaN       NaN
# 2335                                           NaN             NaN       NaN
# 2336                                           NaN             NaN       NaN
# 2337                                           NaN             NaN       NaN
# 2338                                           NaN             NaN       NaN
# 2339                                           NaN             NaN       NaN
# 2340                                           NaN             NaN       NaN
# 2341                                           NaN             NaN       NaN
# 2342                                           NaN             NaN       NaN
# 2343                                           NaN             NaN       NaN
# 2344                                           NaN             NaN       NaN
# 2345                                           NaN             NaN       NaN
# 2346                                           NaN             NaN       NaN
# 2347                                           NaN             NaN       NaN
# 2348                                           NaN             NaN       NaN
# 2349                                           NaN             NaN       NaN
# 2350                                           NaN             NaN       NaN
# 2351                                           NaN             NaN       NaN
# 2352                                           NaN             NaN       NaN
#
#                    is_retweet  retweet_count              source  \
# id
# 935152378747195392      False         8437.0  Twitter for iPhone
# 935150368207654912      False         7176.0  Twitter for iPhone
# 935147410472480769      False        23496.0  Twitter for iPhone
# 934961858380955648      False        14581.0  Twitter for iPhone
# 934896989539586054      False        30416.0  Twitter for iPhone
# 934792302341521408      False        16170.0  Twitter for iPhone
# 934781939088629761      False        24388.0  Twitter for iPhone
# 934563828834164739      False        18789.0  Twitter for iPhone
# 934551607596986368      False        32367.0  Twitter for iPhone
# 934542257222451206      False         9692.0  Twitter for iPhone
# 934539256940417024      False        14346.0  Twitter for iPhone
# 934507210385829888      False        10907.0  Twitter for iPhone
# 934189999045693441      False        43460.0  Twitter for iPhone
# 934131805409697792      False        20792.0  Twitter for iPhone
# 934080974773776384      False        33444.0  Twitter for iPhone
# 934031535757582336      False        15407.0  Twitter for iPhone
# 934029886842458112      False        15964.0  Twitter for iPhone
# 934026050388013056      False        15022.0  Twitter for iPhone
# 933921775984967681      False        15023.0  Twitter for iPhone
# 933918671503753216      False        12073.0  Twitter for iPhone
# 933917690552573952       True         7455.0  Twitter for iPhone
# 933917415028772864       True         6882.0  Twitter for iPhone
# 933837062293291008      False        18708.0  Twitter for iPhone
# 933831194558582784      False        11032.0    Twitter for iPad
# 933720598383026176      False        24547.0        Media Studio
# 933692459351265280      False         8557.0  Twitter for iPhone
# 933662564587855877      False        37143.0  Twitter for iPhone
# 933659179348299776      False         4083.0  Twitter for iPhone
# 933658521828315136      False        44285.0  Twitter for iPhone
# 933517194142584833      False        10344.0  Twitter for iPhone
# ...                       ...            ...                 ...
# 2323                      NaN            NaN                 NaN
# 2324                      NaN            NaN                 NaN
# 2325                      NaN            NaN                 NaN
# 2326                      NaN            NaN                 NaN
# 2327                      NaN            NaN                 NaN
# 2328                      NaN            NaN                 NaN
# 2329                      NaN            NaN                 NaN
# 2330                      NaN            NaN                 NaN
# 2331                      NaN            NaN                 NaN
# 2332                      NaN            NaN                 NaN
# 2333                      NaN            NaN                 NaN
# 2334                      NaN            NaN                 NaN
# 2335                      NaN            NaN                 NaN
# 2336                      NaN            NaN                 NaN
# 2337                      NaN            NaN                 NaN
# 2338                      NaN            NaN                 NaN
# 2339                      NaN            NaN                 NaN
# 2340                      NaN            NaN                 NaN
# 2341                      NaN            NaN                 NaN
# 2342                      NaN            NaN                 NaN
# 2343                      NaN            NaN                 NaN
# 2344                      NaN            NaN                 NaN
# 2345                      NaN            NaN                 NaN
# 2346                      NaN            NaN                 NaN
# 2347                      NaN            NaN                 NaN
# 2348                      NaN            NaN                 NaN
# 2349                      NaN            NaN                 NaN
# 2350                      NaN            NaN                 NaN
# 2351                      NaN            NaN                 NaN
# 2352                      NaN            NaN                 NaN
#
#                                                                  text
# id
# 935152378747195392  The Tax Cut Bill is coming along very well, gr...
# 935150368207654912  The good news is that their ratings are terrib...
# 935147410472480769  We should have a contest as to which of the Ne...
# 934961858380955648  Back in D.C., big week for Tax Cuts and many o...
# 934896989539586054  Since the first day I took office, all you hea...
# 934792302341521408  I endorsed Luther Strange in the Alabama Prima...
# 934781939088629761  The last thing we need in Alabama and the U.S....
# 934563828834164739  Wow, even I didn’t realize we did so much. Wis...
# 934551607596986368  .@FoxNews is MUCH more important in the United...
# 934542257222451206  Check out the recent Editorial in the Wall Str...
# 934539256940417024  The Consumer Financial Protection Bureau, or C...
# 934507210385829888  Happy #SmallBusinessSaturday!\n\nA great day t...
# 934189999045693441  Time Magazine called to say that I was PROBABL...
# 934131805409697792  Will be calling the President of Egypt in a sh...
# 934080974773776384  Horrible and cowardly terrorist attack on inno...
# 934031535757582336  After Turkey call I will be heading over to Tr...
# 934029886842458112  Will be speaking to President Recep Tayyip Erd...
# 934026050388013056  Can you believe that the disrespect for our Co...
# 933921775984967681          Two great people! https://t.co/5cVnMhnmuH
# 933918671503753216  A great guy (with great ratings)! https://t.co...
# 933917690552573952  RT @DeptofDefense: #HappyThanksgiving from @US...
# 933917415028772864  RT @Scavino45: Today, @POTUS @realDonaldTrump ...
# 933837062293291008  ObamaCare premiums are going up, up, up, just ...
# 933831194558582784  My great honor to join our incredible men and ...
# 933720598383026176        HAPPY THANKSGIVING! https://t.co/nQhi7XopMW
# 933692459351265280  Will be doing a live Thanksgiving Video Teleco...
# 933662564587855877                          MAKE AMERICA GREAT AGAIN!
# 933659179348299776           @ThePlumLineGS MAKE AMERICA GREAT AGAIN!
# 933658521828315136  HAPPY THANKSGIVING, your Country is starting t...
# 933517194142584833  ....And it will get even better with Tax Cuts!...
# ...                                                               ...
# 2323                Republicans must be careful in that the Dems o...
# 2324                things they did and said (like giving the ques...
# 2325                Somebody hacked the DNC but why did they not h...
# 2326                Thank you to Ford for scrapping a new plant in...
# 2327                "@FoxNews: Julian Assange on U.S. media covera...
# 2328                Julian Assange said "a 14 year old could have ...
# 2329                The "Intelligence" briefing on so-called "Russ...
# 2330                I will be having a general news conference on ...
# 2331                "Trump is already delivering the jobs he promi...
# 2332                There should be no further releases from Gitmo...
# 2333                Instead of driving jobs and wealth away, AMERI...
# 2334                "@DanScavino: Ford to scrap Mexico plant, inve...
# 2335                ........may be, their number one act and prior...
# 2336                With all that Congress has to work on, do they...
# 2337                The Democrat Governor.of Minnesota said "The A...
# 2338                People must remember that ObamaCare just doesn...
# 2339                General Motors is sending Mexican made model o...
# 2340                China has been taking out massive amounts of m...
# 2341                North Korea just stated that it is in the fina...
# 2342                I thought and felt I would win big, easily ove...
# 2343                Various media outlets and pundits say that I t...
# 2344                @CNN just released a book called "Unprecedente...
# 2345                Chicago murder rate is record setting - 4,331 ...
# 2346                Well, the New Year begins. We will, together, ...
# 2347                RT @IvankaTrump: 2016 has been one of the most...
# 2348                RT @DonaldJTrumpJr: Happy new year everyone. #...
# 2349                RT @EricTrump: 2016 was such an incredible yea...
# 2350                RT @Reince: Happy New Year + God's blessings t...
# 2351                RT @DanScavino: On behalf of our next #POTUS &...
# 2352                TO ALL AMERICANS- #HappyNewYear & many blessin...
#
# [4706 rows x 7 columns]

# %%
#Should we use lower case of texts here ?.lower()
def CreateDictionary(df):
    textDict={}
    for i in range(len(df)):
        t=df.iloc[i]["text"]
        splitT=t.split(" ")
        for s in splitT:
            if(textDict.get(s)==None):
                textDict[s]=1
            else:
                textDict[s]+=1
    return textDict
            
textDict=CreateDictionary(df)

# %%
trumpDict=pd.DataFrame.from_dict(list(textDict.items()))
trumpDict.rename(columns={0:"words",1:"occurences"},inplace=True)
trumpDict.sort_values("occurences",ascending=False,inplace=True)


#DF of all hashtags
trumpDict[trumpDict["words"].str.contains("#")]
# Out:
#                                                    words  occurences
# 1130                                              #USA🇺🇸          46
# 2945                                               #MAGA          31
# 1143                                           #FakeNews          22
# 5834                                             #MAGA🇺🇸          21
# 5353                                    #HurricaneHarvey          20
# 2542                                          #TaxReform          19
# 4510                                               #UNGA          15
# 1232                                              #MAGA!          14
# 1361                                           #APEC2017          14
# 6440                                     #AmericaFirst🇺🇸          13
# 3557                                         #PuertoRico          12
# 3260                                    #WeeklyAddress🇺🇸          11
# 4505                                             #Harvey          10
# 6543                                                #USA           9
# 7741                                             #ICYMI-           9
# 6070                                               #Fake           8
# 7429                                          #G20Summit           7
# 2384                                           #JFKFiles           6
# 3916                                               #FEMA           6
# 4029                                               #LESM           6
# 2583                                              #Dobbs           6
# 6695                                               #MS13           6
# 7808                                          #Obamacare           6
# 1325                                              #NoKo.           6
# 8273                                             #ICYMI:           6
# 6739                                        #TeamScalise           5
# 4546                                          #USAatUNGA           5
# 8213                                         #Obamacare.           4
# 8232                                      #AmericaFirst!           4
# 8619                                        #POTUSAbroad           4
# ...                                                  ...         ...
# 1584                        Korea🇺🇸🇰🇷\n#NationalAssembly           1
# 6705                                  \n#FlashbackFriday           1
# 8703         #WeeklyAddress🇺🇸\n➡️https://t.co/uT4K4fh88Y           1
# 7687   \n#UnleashingAmericanEnergy\nhttps://t.co/hlM7...           1
# 7688               AGAIN!\n\n#NoSanctuaryForCriminalsAct           1
# 7689                                         \n#KatesLaw           1
# 7693               bills:\n☑️#NoSanctuaryForCriminalsAct           1
# 7694                                       \n☑️#KatesLaw           1
# 10740                        AMERICAN!\n#InaugurationDay           1
# 10765                         family!\n#Inauguration2017           1
# 3906                                       \n#PRStrong🇵🇷           1
# 3910                             #FakeNews!\n#PRStrong🇵🇷           1
# 6825   Melania!\n#MakeAmericaGreatAgain🇺🇸\n🎥https://t...           1
# 3996                    High\n☑️#MakeAmericaGreatAgain🇺🇸           1
# 3953          #VirginIslands”\n\nhttps://t.co/gonmsZusSe           1
# 4125                        @SteveScalise!\n#TeamScalise           1
# 6546       Virginia!\n#MakeAmericaGreatAgain🇺🇸\nTickets:           1
# 4303                      Country.\n#StandForOurAnthem🇺🇸           1
# 6574                                           #RAISEAct           1
# 266                         #SmallBusinessSaturday!\n\nA           1
# 5101   Americans🇺🇸#IrmaHurricane2017\n🎥https://t.co/j...           1
# 8566                              resolve.\n#NATOMeeting           1
# 9542                            country!\n#WeeklyAddress           1
# 8634         #WeeklyAddress🇺🇸\n➡️https://t.co/UYEhgch4Hl           1
# 8639                       #PoliceWeek"\nProclamation➡️…           1
# 9452             #CEOTownHall\n➡️https://t.co/ADSKuUXf1b           1
# 472                           today!\n#HappyThanksgiving           1
# 9487                         \n#WorldAutismAwarenessDay.           1
# 8618          ➡️https://t.co/VtmlSqciXx\n\n#RiyadhSummit           1
# 7895                             AGAIN!\n#AmericaFirst🇺🇸           1
#
# [403 rows x 2 columns]

# %% [markdown]
# ## Sentiment Analysis

# %%
from aylienapiclient import textapi
import csv
import time
client = textapi.Client("9a0daca1", "62fbf9df3887a46f0e59e3815a958b6a")
sentiment = client.Sentiment({'text': "Make America Great Again!"})
print(sentiment)
# Out:
# {'polarity': 'positive', 'subjectivity': 'objective', 'text': 'Make America Great Again!', 'polarity_confidence': 0.9765748381614685, 'subjectivity_confidence': 0.9982027963959077}

# %%
def analyse(tweet):
    text = tweet['text'].strip()
    sleepTime = 4
    if len(text) == 0:
        print('** skipped')
        return None
    while(True):
        try:
            sentiment = client.Sentiment({'text': text})
            sentiment['id'] = tweet.name
            print(text)
            return sentiment
        except:
            print("Sleeping... (time:", sleepTime, ")")
            time.sleep(sleepTime)
            sleepTime *= 2

def analyseTweets(df, batch_size=100):
    i = 0
    sentiments = pd.DataFrame()
    while(i <= len(df)):
        batch = df[i:(i + batch_size)].apply(analyse, axis=1).tolist()
        t0 = time.time()
        new = pd.DataFrame(batch).set_index('id')
        t1 = time.time()
        print("DataFrame(): %f" % (t1 - t0))
        t0 = time.time()
        sentiments = sentiments.append(new)
        t1 = time.time()
        print("tolist(): %f" % (t1 - t0))
        time.sleep(batch_size // 10)
        i += batch_size
        print("Tweets analysed:", i)
    return sentiments

sentiments = analyseTweets(df)
sentiments.to_csv('sentiments.csv')

# %% [markdown]
# ## Clustering

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Michele\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import RegexpTokenizer
from nltk.stem.porter import PorterStemmer
from stop_words import get_stop_words
from gensim import corpora, models
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
# %pylab inline
import re
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\Michele\Anaconda3\lib\site-packages\IPython\core\magics\pylab.py:161: UserWarning: pylab import has clobbered these variables: ['zeros']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
def preProcess_procedure(tweet):
    original = tweet
    tweet = re.sub(r'([a-z]+)\.([A-Z].+)', '\1 \2', tweet)
    tweet = tweet.lower()
    tweet = re.sub(r'https?:\/\/.*[\r\n]*', '', tweet)
    tweet = re.sub(r'(\d+[:\/,\.])+\d+ *([ap]\.?m\.?)?', '', tweet)
    tokenizer = RegexpTokenizer(r'[a-z_@#][a-z0-9_\'\.]+[a-z0-9_]')
    tweet = tokenizer.tokenize(tweet)
    stopwords = get_stop_words('en')
    stopwords.append('amp')
    p_stemmer = PorterStemmer()
    tweet = [i for i in tweet if not i in stopwords]
    tweet = [p_stemmer.stem(i) for i in tweet]
    #print(original, "=>", tweet)
    return tweet
    
def preProcess(tweets, ratio=0.8):
    tweets.index = range(len(tweets))
    indices = np.random.permutation(tweets.index)
    train_len = int(len(tweets) * ratio)
    train_indices = indices[:train_len]
    test_indices = indices[train_len:]
    orig_test = tweets[test_indices]
    tweets = tweets.map(preProcess_procedure)
    dictionary = corpora.Dictionary(tweets)
    train = [dictionary.doc2bow(tweets[tweet]) for tweet in train_indices]
    test = [dictionary.doc2bow(tweets[tweet]) for tweet in test_indices]
    return train, test, orig_test, dictionary
    
train, ltest, orig_test, dictionary = preProcess(df['text'])

# %%
lda = models.ldamodel.LdaModel(train, num_topics=100, id2word = dictionary, passes=20)

# %%
lda[ltest[0]]
# Out:
# [(6, 0.21995119512666339),
#  (15, 0.076160229839429217),
#  (65, 0.26503354352285829),
#  (78, 0.15599788865390715),
#  (92, 0.21500000000000027)]

# %%
# Show Clustering
i = 0
for tweet in ltest:
    print(orig_test.iloc[i], "\n")
    print(sorted(lda[tweet], key=lambda tup: tup[1], reverse=True), "\n")
    i += 1
# Out:
# Despite the Fake News Media in conjunction with the Dems, an amazing job is being done in Puerto Rico. Great people!
#
# [(65, 0.26505135905331717), (6, 0.21979489941352448), (92, 0.21500000000000027), (78, 0.1561252481148504), (15, 0.076171350561166015)]
#
# At 9:00 P.M. @CNN, of all places, is doing a Special Report on my daughter, Ivanka. Considering it is CNN, can't imagine it will be great!
#
# [(70, 0.44734394453819309), (94, 0.29097871312862611), (73, 0.09504024224990229), (88, 0.086637100083278865)]
#
# RT @DRUDGE_REPORT: GREAT AGAIN: FEDS ARREST MURDER SUSPECT IN 'FAST AND FURIOUS' SCANDAL... https://t.co/clOLxTE3D4
#
# [(2, 0.26917182144655138), (52, 0.16282988109950505), (48, 0.15500970875221304), (23, 0.11167172093472227), (49, 0.10631686776700991), (55, 0.10100000000000024)]
#
# Was with great people last night in Fort Myer, Virginia. The future of our country is strong!
#
# [(75, 0.37272752667334613), (80, 0.32531378350982587), (0, 0.21377687163501147)]
#
# I hereby demand a second investigation, after Schumer, of Pelosi for her close ties to Russia, and lying about it. https://t.co/qCDljfF3wN
#
# [(52, 0.91000000000000092)]
#
# It was an honor to welcome Republican and Democratic members of the Senate Finance Committee to the @WhiteHouse today. #TaxReform https://t.co/ge4Xic9fId
#
# [(42, 0.36285462621420861), (41, 0.25289104599810458), (31, 0.16750000000000018), (2, 0.13675432778768762)]
#
# It was an honor to welcome the Prime Minister of Denmark, Lars Løkke Rasmussen {@larsloekke} to the @WhiteHouse yes…
#
# [(42, 0.33717228167790786), (12, 0.29926905058630909), (86, 0.14805237173044569), (5, 0.1355062960053387)]
#
# Nick Adams, "Retaking America"  "Best things of this presidency aren't reported about. Convinced this will be perhaps best presidency ever."
#
# [(55, 0.26733333333333353), (73, 0.25478755767321004), (50, 0.13862546189416458), (40, 0.10789470516599267), (34, 0.10058484418722634), (81, 0.068107431079406866)]
#
# ...and did not want to "rock the boat." He didn't "choke," he colluded or obstructed, and it did the Dems and Crooked Hillary no good.
#
# [(59, 0.19264011248555246), (65, 0.18188056203672082), (45, 0.1322661498488904), (85, 0.11970152100218806), (15, 0.10532983644483125), (80, 0.091818181818181965), (4, 0.091818181818181951)]
#
# @NYGovCuomo @NYCMayor ...fully supports any and all of their efforts with respect to the West Side attack. #NYCStrong
#
# [(61, 0.9100000000000007)]
#
# Ron Estes is running TODAY for Congress in the Great State of Kansas. A wonderful guy, I need his help on Healthcare &amp; Tax Cuts (Reform).
#
# [(68, 0.4138971843056144), (15, 0.22087824813990051), (95, 0.13748468834156508), (12, 0.10918769289759669), (64, 0.062669833374147457)]
#
# My warmest condolences and sympathies to the victims and families of the terrible Las Vegas shooting. God bless you!
#
# [(61, 0.22671010524042542), (8, 0.20511594952844858), (55, 0.16750000000000026), (58, 0.16750000000000023), (27, 0.15400727856446017)]
#
# We are going to defend our industry &amp; create a level playing field for the American worker. It is time to put… https://t.co/dzPKJMghj1
#
# [(24, 0.30612530730185955), (25, 0.2891562614458153), (32, 0.22591104339637122), (18, 0.098807387855955109)]
#
# Meeting w/ Washington, D.C. @MayorBowser and Metro GM Paul Wiedefeld about incoming winter storm preparations here…
#
# [(17, 0.50083333333333391), (3, 0.25083333333333352), (0, 0.08416666666666682), (13, 0.08416666666666682)]
#
# RT @Reince45: Promise kept. @POTUS exits flawed #ParisAccord to seek better deal for U.S. workers &amp; economy. This WH will always put #Ameri…
#
# [(40, 0.79184075436252066), (85, 0.15371480119303418)]
#
# With all of the recently reported electronic surveillance, intercepts, unmasking and illegal leaking of information, I have no idea...
#
# [(43, 0.4433683854120134), (44, 0.19792482455302038), (33, 0.16752972090152543), (51, 0.10390434186071446)]
#
# Ed Gillespie will be a great Governor of Virginia. His opponent doesn't even show up to meetings/work, and will be VERY weak on crime!
#
# [(6, 0.42286363310044922), (82, 0.19507933992705664), (97, 0.15880399688550809), (53, 0.1546816015155589)]
#
# Speech transcript at Arab Islamic American Summit ➡️
#
# [(34, 0.28714285714285764), (76, 0.28714285714285764), (98, 0.16759520686940471), (49, 0.12097622170202442)]
#
# HAPPY 70th BIRTHDAY to the @USAirForce! The American people are eternally grateful. Thank you for keeping America PROUD, STRONG and FREE!
#
# [(46, 0.42527617146705965), (17, 0.26040231558119747), (93, 0.14432419720385506), (62, 0.10142588717646023)]
#
# Was the brother of John Podesta paid big money to get the sanctions on Russia lifted? Did Hillary know?
#
# [(14, 0.48318256804643323), (36, 0.18500659579731207), (57, 0.095349860306989165), (54, 0.085691745080035936), (23, 0.077692307692307797)]
#
# The massive TAX CUTS/REFORM that I have submitted is moving along in the process very well, actually ahead of schedule. Big benefits to all!
#
# [(63, 0.40365054743939366), (68, 0.239003648970191), (37, 0.20066666666666683), (44, 0.092679136923749225)]
#
# The🇺🇸has great strength & patience, but if it is forced to defend itself or its allies, we will have no choice but to totally destroy #NoKo.
#
# [(35, 0.20999413153651406), (32, 0.17913495815211), (27, 0.14943987683589102), (70, 0.10514598499224331), (17, 0.097807945536681137), (86, 0.090671464311203112), (49, 0.090305638635358454)]
#
# RT @RealEagleBites: @realDonaldTrump It is the height of hypocrisy. Obama and Clinton in effect gave nuclear weapons to North Korea by thei…
#
# [(39, 0.42928571428571471), (83, 0.14426638962070304), (32, 0.14357142857142871), (36, 0.12898372433110231), (71, 0.086035600333909321)]
#
# Join me live at 9:00 P.M.
# #JointAddress https://t.co/J882zbyVkJ https://t.co/gTtK3vJmkU
#
# [(19, 0.75250000000000317)]
#
# Weekly Address - 11:00 A.M. at the @WhiteHouse! #MAGA🇺🇸
# ➡️https://t.co/YSaPJnSX2i https://t.co/Gb8iTGzb6j
#
# [(3, 0.80200000000000327)]
#
# Marine Plane crash in Mississippi is heartbreaking. Melania and I send our deepest condolences to all!
#
# [(74, 0.60100000000000076), (14, 0.10100000000000017), (34, 0.10100000000000017), (97, 0.10100000000000017)]
#
# Officials behind the now discredited "Dossier" plead the Fifth. Justice Department and/or FBI should immediately release who paid for it.
#
# [(30, 0.21078226183464235), (51, 0.20657098913221744), (64, 0.14357142857142871), (25, 0.12413450038988491), (36, 0.091944115746299085), (57, 0.084425275754099818), (84, 0.072142857142857231)]
#
# ...vast sums of money to NATO &amp; the United States must be paid more for the powerful, and very expensive, defense it provides to Germany!
#
# [(10, 0.64357142857142946), (91, 0.28642857142857181)]
#
# ...Hopefully we will never have to use this power, but there will never be a time that we are not the most powerful nation in the world!
#
# [(74, 0.3811544955891113), (88, 0.22823841111640489), (2, 0.17326347074905221), (69, 0.13734362254543306)]
#
# Thank you!
#
# “Trump’s Defining Speech”
# WSJ Editorial: https://t.co/YuDgVfRroR https://t.co/T0R4u4IHDJ
#
# [(49, 0.43000000000000088), (30, 0.2871428571428577), (61, 0.14428571428571454)]
#
# New polls out today are very good considering that much of the media is FAKE and almost always negative. Would still beat Hillary in .....
#
# [(94, 0.30074993764959024), (92, 0.20724069860915101), (38, 0.12795305910914243), (59, 0.089048356895054012), (44, 0.080159326158354513), (19, 0.072709010052013287), (28, 0.060139611526695474)]
#
# Things are looking great for Karen H!
#
# [(25, 0.53391946926945355), (40, 0.27008053073054894)]
#
# RT @IvankaTrump: Very proud of Arabella and Joseph for their performance in honor of President Xi Jinping and Madame Peng Liyuan's official…
#
# [(25, 0.38538461538461594), (21, 0.29403888064782269), (42, 0.092114965506023938), (33, 0.077692307692307783), (96, 0.077692307692307783)]
#
# I heard poorly rated @Morning_Joe speaks badly of me (don't watch anymore). Then how come low I.Q. Crazy Mika, along with Psycho Joe, came..
#
# [(27, 0.19446356077166957), (37, 0.12208430554335196), (80, 0.094654102916975347), (53, 0.090854397477523607), (98, 0.077149133999953351), (31, 0.067985849929620298), (66, 0.064900720030391351), (86, 0.062990523371782334), (97, 0.062631086197872637), (17, 0.060942536657347106), (87, 0.051899338659068692)]
#
# It was my great honor to deliver the #CGACommencement17 at the @USCGAcademy. CONGRATULATIONS to the Class of 2017!…
#
# [(62, 0.41963285489250429), (42, 0.17514892693491751), (87, 0.15871136429775762), (89, 0.12650685387482147)]
#
# One by one we are keeping our promises - on the border, on energy, on jobs, on regulations. Big changes are happening!
#
# [(79, 0.33931668062453779), (80, 0.22396738178830941), (69, 0.17675723138799027), (4, 0.090995405836317406), (51, 0.08979663369617874)]
#
# On Tuesday, I visited with the incredible men &amp; women of @ICEgov &amp; @DHSgov Border Patrol in Yuma, AZ. Thank you. We respect &amp; cherish you! https://t.co/KSQddGqWzJ
#
# [(7, 0.39489320181394216), (17, 0.16146898606058074), (42, 0.15904216551600872), (22, 0.1427360015769138), (82, 0.074002502175412918)]
#
# As President I wanted to share with Russia (at an openly scheduled W.H. meeting) which I have the absolute right to do, facts pertaining....
#
# [(82, 0.18075780029311603), (72, 0.16309303365798264), (36, 0.16122829110873715), (63, 0.11858714387867569), (93, 0.10646361024645118), (16, 0.10483215661165748), (9, 0.093499502664919548)]
#
# With ZERO Democrats to help, and a failed, expensive and dangerous ObamaCare as the Dems legacy, the Republican Senators are working hard!
#
# [(2, 0.21662991878313206), (10, 0.212849498356844), (76, 0.14901226111212187), (88, 0.11047488166038046), (45, 0.089214246352395082), (15, 0.08322128640439673), (64, 0.07216933590215964)]
#
# Crooked Hillary Clinton blames everybody (and every thing) but herself for her election loss. She lost the debates and lost her direction!
#
# [(14, 0.29909541705525899), (52, 0.27376172580188463), (19, 0.20526042531692532), (20, 0.081882431825932189), (17, 0.072142857142857231)]
#
# Wow, looks like James Comey exonerated Hillary Clinton long before the investigation was over...and so much more. A rigged system!
#
# [(64, 0.36184084433511782), (33, 0.2631052646704623), (26, 0.19954505581021778), (96, 0.11150883518420289)]
#
# Our country needs strong borders and extreme vetting, NOW. Look what is happening all over Europe and, indeed, the world - a horrible mess!
#
# [(82, 0.38520116197541693), (79, 0.2137674717266263), (48, 0.14170108980875257), (18, 0.11708429541036743), (15, 0.078912647745504425)]
#
# The #USSJohnFinn will provide essential capabilities to keep America safe. Our sailors are the best anywhere in the world. Congratulations!
#
# [(46, 0.22361352331555234), (81, 0.18308417726143519), (6, 0.095000291896418412), (97, 0.094860406346967033), (50, 0.08749032208930356), (63, 0.085669856687782098), (62, 0.083374839837971601), (49, 0.081192296850284756)]
#
# Why would I call China a currency manipulator when they are working with us on the North Korean problem? We will see what happens!
#
# [(32, 0.33873006736559724), (9, 0.31152914450327868), (50, 0.16962435820394176), (79, 0.10011642992718375)]
#
# Ivanka on @foxandfriends now!
#
# [(70, 0.50250000000000072), (22, 0.25250000000000039)]
#
# General Kelly is doing a great job at the border. Numbers are way down. Many are not even trying to come in anymore.
#
# [(67, 0.34476964713310482), (90, 0.33618736136917199), (31, 0.08597089744765285), (8, 0.080351067027319575), (82, 0.079644103945828562)]
#
# In NYC, looks like another attack by a very sick and deranged person. Law enforcement is following this closely. NOT IN THE U.S.A.!
#
# [(61, 0.28642857142857164), (40, 0.22558883026753271), (59, 0.19845632425345947), (97, 0.14764152839838418), (3, 0.074027602794909816)]
#
# country and with the massive cost reductions I have negotiated on military purchases and more, I believe the people are seeing "big stuff."
#
# [(74, 0.39413405582865468), (79, 0.25298235613942655), (45, 0.10126221775140085), (93, 0.10085213951128798), (1, 0.077692307692307755)]
#
# MAKE AMERICA GREAT AGAIN! https://t.co/3eYF3nir4B
#
# [(81, 0.75250000000000061)]
#
# Thank you Jacob! https://t.co/Wjjrv6KTVT
#
# [(51, 0.67000000000000226)]
#
# We have made more progress in the last nine months against ISIS than the Obama Administration has made in 8 years.Must be proactive &amp; nasty!
#
# [(36, 0.44677920213283207), (34, 0.14697891605271446), (61, 0.1082170369306112), (99, 0.10202484488384331), (0, 0.1010000000000001)]
#
# Ralph Northam will allow crime to be rampant in Virginia. He’s weak on crime, weak on our GREAT VETS, Anti-Second Amendment....
#
# [(82, 0.42071567927137332), (6, 0.31481147490575367), (59, 0.071519582076915209), (52, 0.070453263745936592), (96, 0.063125000000000084)]
#
# Democrats are smiling in D.C. that the Freedom Caucus, with the help of Club For Growth and Heritage, have saved Planned Parenthood & Ocare!
#
# [(0, 0.62157034498281338), (59, 0.30842965501718811)]
#
# Thank you to former campaign adviser Michael Caputo for saying so powerfully that there was no Russian collusion in our winning campaign.
#
# [(27, 0.92384615325274944)]
#
# RT @Scavino45: Florida Governor Rick @FLGovScott. #HurricaineIrma
#
# [(90, 0.45727435581035664), (55, 0.25986850133250144), (14, 0.14428571428571443)]
#
# RT @KatiePavlich: Your boss pardoned a traitor who gave U.S. enemies state secrets, he also pardoned a terrorist who killed Americans. Spar…
#
# [(8, 0.93812499752643752)]
#
# ...they do NOTHING for us with North Korea, just talk. We will no longer allow this to continue. China could easily solve this problem!
#
# [(32, 0.49249456130329022), (51, 0.18381497382942996), (36, 0.093053650004614727), (40, 0.0820723568649004), (2, 0.080707315140622807)]
#
# Very much enjoyed my tour of the Smithsonian's National Museum of African American History and Culture...A great job done by amazing people!
#
# [(8, 0.48246797968277938), (93, 0.2884181430728841), (78, 0.093347305784436396), (11, 0.075766571459901205)]
#
# The United States made some of the worst Trade Deals in world history.Why should we continue these deals with countries that do not help us?
#
# [(85, 0.87625000000000031)]
#
# I am very supportive of the Senate #HealthcareBill. Look forward to making it really special! Remember, ObamaCare is dead.
#
# [(26, 0.53303268148894367), (2, 0.12575734473348946), (90, 0.08881072301245066), (81, 0.08683275381715079), (0, 0.086399830281300494)]
#
# I will be going to Puerto Rico on Tuesday with Melania. Will hopefully be able to stop at the U.S. Virgin Islands (people working hard).
#
# [(2, 0.17736590396650731), (76, 0.1565844464488565), (10, 0.14952563800194363), (65, 0.14231333441023672), (84, 0.13894533704788631), (15, 0.12867054923135021), (42, 0.051888908540277862)]
#
# Getting ready to visit Walter Reed Medical Center with Melania. Looking forward to seeing our bravest and greatest Americans!
#
# [(7, 0.39855872057336711), (26, 0.23710633323070593), (93, 0.14330561226485322), (10, 0.08825472117110808), (19, 0.069441279426633501)]
#
# From @FoxNews "Bombshell: In 2016, Obama dismissed idea that anyone could rig an American election."  Check out his statement - Witch Hunt!
#
# [(73, 0.49757926862987023), (19, 0.21499999999911087), (7, 0.074631946837725893), (58, 0.072788784533294043), (56, 0.072142857142857231)]
#
# An old picture with Nancy and Ronald Reagan.
#
# [(91, 0.66833333333333345), (79, 0.16833333333333339)]
#
# An honor to join the @FaithandFreedom Coalition yesterday. In America, we don't worship government. We worship God.… https://t.co/1ds8BrzUQe
#
# [(77, 0.5093928481997585), (27, 0.197018732761091), (19, 0.10905895627257879), (42, 0.09725673549373727)]
#
# People are anxiously awaiting my decision as to who the next head of the Fed will be.... 🎥
#
# [(36, 0.65306074747475751), (23, 0.12044058611611899), (38, 0.11872088863134693)]
#
# Today, it was my privilege to welcome survivors of the #USSArizona to the WH. Remarks:
#
# [(80, 0.57285714285714384), (42, 0.28714285714285764)]
#
# RT @RightlyNews: @realDonaldTrump @LouDobbs It is NOT a coincidence that the economy boomed immediately after the 2016 election.
#
# [(0, 0.43360654189433551), (6, 0.33444444444444521), (84, 0.12417123588344357)]
#
# ....and has been horrible on Virginia economy. Vote @EdWGillespie today!
#
# [(9, 0.33558093360954255), (6, 0.23870478067617334), (15, 0.14428605304168701), (2, 0.14428537552974233)]
#
# Just spoke to President Macri of Argentina about the five proud and wonderful men killed in the West Side terror attack. God be with them!
#
# [(44, 0.20317045200937356), (90, 0.14885765031850848), (30, 0.12071723167315485), (10, 0.085961911682869804), (58, 0.084775836665513582), (41, 0.081003438770369737), (27, 0.075661414854295991), (70, 0.074194191460878633), (75, 0.068782872565036235)]
#
# RT @foxandfriends: Getting the job done! Sen. Mitch McConnell delays August recess to work on health care bill
#
# [(28, 0.37378073627695624), (64, 0.32508801179410529), (98, 0.23646458526227265)]
#
# Thank you for joining me in Mandan, ND Gov. @DougBurgum, Lt. Gov. @BrentSanfordND, @SenJohnHoeven, @RepKevinCramer &amp; @SenatorHeitkamp. https://t.co/8nIvtHvpu6
#
# [(71, 0.78732270187581299), (19, 0.1235863890332785)]
#
# Great meeting w/ NATO Sec. Gen. We agreed on the importance of getting countries to pay their fair share &amp; focus on… https://t.co/G9TdjWezmH
#
# [(24, 0.27802941389966113), (64, 0.24154612344715198), (53, 0.1565544371833828), (9, 0.10328062635635547), (20, 0.081263164667382703), (77, 0.072183377303209867)]
#
# Happy Lá Fheile Phadraig to all of my great Irish friends!
#
# [(68, 0.55775461495326073), (66, 0.15692567907619556), (17, 0.14674827739911592)]
#
# I cannot imagine that these very fine Republican Senators would allow the American people to suffer a broken ObamaCare any longer!
#
# [(2, 0.36406275790932724), (16, 0.19147415211498123), (94, 0.1880386636080742), (73, 0.17642442636761879)]
#
# RT @foxandfriends: Hannity: Russia allegations 'boomeranging back' on Democrats https://t.co/lvdrpxpcp9
#
# [(80, 0.25125000000000047), (65, 0.24854679547778072), (7, 0.12895320314074155), (22, 0.12625000000000025), (79, 0.12624999974935638)]
#
# Republican Senators will not let the American people down! ObamaCare premiums and deductibles are way up - it was a lie and it is dead!
#
# [(2, 0.27566887159927644), (65, 0.23713407679664772), (73, 0.13387560587329519), (74, 0.12211194236060063), (25, 0.081209503370181235), (0, 0.077692307692307797)]
#
# JFK Files are being carefully released. In the end there will be great transparency. It is my hope to get just about everything to public!
#
# [(51, 0.43771190916096364), (50, 0.14810856941917008), (2, 0.10769703835577642), (36, 0.087084415048320346), (98, 0.078920929447733074), (77, 0.073334281425180156)]
#
# Really great numbers on jobs & the economy! Things are starting to kick in now, and we have just begun! Don't like steel & aluminum dumping!
#
# [(81, 0.35455792185283402), (63, 0.28719621846985149), (26, 0.23297179699254814), (40, 0.065274062684767237)]
#
# Jerry Falwell of Liberty University was fantastic on @foxandfriends. The Fake News should listen to what he had to say. Thanks Jerry!
#
# [(13, 0.554308131052903), (92, 0.20675503482967802), (22, 0.16432144950203556)]
#
# Just read the nice remarks by President Jimmy Carter about me and how badly I am treated by the press (Fake News). Thank you Mr. President!
#
# [(48, 0.69073809571923617), (92, 0.15716383045704702), (76, 0.087431407139341805)]
#
# Thank you to General Motors and Walmart for starting the big jobs push back into the U.S.!
#
# [(85, 0.4523103388101401), (68, 0.24140318341646258), (79, 0.21810465959157974)]
#
# Departing The Pentagon after meetings with @VP Pence, Secretary James Mattis, and our great teams. #MAGA🇺🇸 https://t.co/5d1MSzhjQS
#
# [(24, 0.36506288199477266), (66, 0.18047644162253987), (30, 0.10736142860479637), (74, 0.094343239662635719), (53, 0.090256008115256373), (33, 0.084166666666666778)]
#
# "Dow Passes 23,000 for the First Time, Fueled by Strong Earnings"
# #Dow23K📈https://t.co/wnkrddYlb9 https://t.co/wlP0NCNcou
#
# [(78, 0.26491248281754143), (73, 0.22333333333333372), (3, 0.15880217366436641), (52, 0.13517423240698201), (23, 0.11222222222222242)]
#
# The good news is that their ratings are terrible, nobody cares! https://t.co/I7h4Ryin3h
#
# [(63, 0.23873881458492774), (92, 0.2171312992815887), (73, 0.2135644797762421), (51, 0.19342254921438512)]
#
# FEMA and first responders are working hard (yet again) on Hurricane Nate. Military helping. Very much under control!
#
# [(88, 0.31647064480162845), (47, 0.26369635270837394), (76, 0.18364918484883483), (66, 0.085414586871932666), (59, 0.077692307692307769)]
#
# Great win in Kansas last night for Ron Estes, easily winning the Congressional race against the Dems, who spent heavily & predicted victory!
#
# [(15, 0.50104937977042163), (98, 0.29449371874855446), (0, 0.14739807795161314)]
#
# RT @JacobAWohl: @realDonaldTrump President Trump alone has succeeded in bringing the Stock Market, Small Business Index and Consumer Comfor…
#
# [(71, 0.27595482869483101), (89, 0.16605452289368), (34, 0.11183540779639513), (48, 0.094861496809346135), (73, 0.074935960589462808), (79, 0.072073339581216103), (58, 0.071777097745955101), (39, 0.071174012555781097)]
#
# All of my Cabinet nominee are looking good and doing a great job. I want them to be themselves and express their own thoughts, not mine!
#
# [(38, 0.33027288581294972), (90, 0.23329298629056958), (2, 0.18956834743280912), (65, 0.15959305319094591)]
#
# I am pleased to inform you that I have just named General/Secretary John F Kelly as White House Chief of Staff. He is a Great American....
#
# [(67, 0.46730059781692196), (54, 0.14462611779393372), (24, 0.11844114080802491), (62, 0.071433303440452942), (3, 0.068198840140667294), (33, 0.067333333333333398)]
#
# ICYMI- This week we hosted a #MadeInAmerica event, right here at the @WhiteHouse! If it is MADE IN AMERICA, it is the BEST! USA🇺🇸
#
# [(29, 0.25083333333333363), (48, 0.2283901238320975), (87, 0.1166337727923195), (35, 0.10314687441295391), (50, 0.085636023269682254), (8, 0.084166666666666751), (81, 0.053693205692947443)]
#
# The Dems want to stop tax cuts, good healthcare and Border Security.Their ObamaCare is dead with 100% increases in P's. Vote now for Karen H
#
# [(68, 0.32238087584867853), (15, 0.21518397703562386), (82, 0.20459924304674251), (65, 0.15116923740229016)]
#
# RT @FLOTUS: Looking forward to hosting the annual Easter Egg Roll at the @WhiteHouse on Monday!
#
# [(55, 0.45545454545454578), (65, 0.45545454545454578)]
#
# .@DanaPerino &amp; @BradThor,
# Thank you so much for the wonderful compliment. Working hard! #MAGA https://t.co/AKWlsMsCVH
#
# [(83, 0.58284254735533181), (38, 0.188409009564072), (76, 0.13174844308059716)]
#
# Next Saturday night I will be holding a BIG rally in Pennsylvania. Look forward to it!
#
# [(75, 0.80403068818915024), (36, 0.10687840271994108)]
#
# We traveled the world to strengthen long-standing alliances, and to form new partnerships. See more at:…
#
# [(46, 0.53041043970003265), (18, 0.10447359846258826), (73, 0.098288066063200341), (23, 0.096190868557938874), (28, 0.084273390852604838)]
#
# will only get higher. Car companies and others, if they want to do business in our country, have to start making things here again. WIN!
#
# [(85, 0.27771505871396451), (81, 0.23242189817726064), (90, 0.15051239760619081), (65, 0.1050306258932268), (40, 0.085394862354803661), (34, 0.081782300111697348)]
#
# Toyota &amp; Mazda to build a new $1.6B plant here in the U.S.A. and create 4K new American jobs. A great investment in American manufacturing!
#
# [(24, 0.31922397032965444), (91, 0.25501746850490836), (85, 0.23362075524163062), (28, 0.12813780592380747)]
#
# ...But while Dallas dropped to it knees as a team, they ALL stood up for our National Anthem. Big progress being made - we love our country!
#
# [(19, 0.92384615384615509)]
#
# FAKE NEWS media knowingly doesn't tell the truth. A great danger to our country. The failing @nytimes has become a joke. Likewise @CNN. Sad!
# [(92, 0.2971836519224933), (31, 0.20803596837081398), (88, 0.1837597228809256), (64, 0.13262162817045001), (70, 0.062851581497282719), (73, 0.060253329471081196)]
#
# Thank you Sean McGarvey &amp; the entire Governing Board of Presidents for honoring me w/an invite to speak. #NABTU2017… https://t.co/dJlZvlq6Tj
#
# [(22, 0.61298165850880237), (66, 0.22183091983842121), (88, 0.084354088306880626)]
#
# RT @EricTrump: Thank you to @GolfDigest for this incredible feature! "Golfer-in-Chief" @RealDonaldTrump https://t.co/vpdY4jNbI4 https://t.c…
#
# [(43, 0.40672404995260619), (17, 0.31721314704711523), (67, 0.16828502522250247)]
#
# IN AMERICA WE DON'T WORSHIP GOVERNMENT - WE WORSHIP GOD!🎥https://t.co/jIejSgVnnA
#
# [(77, 0.83500000000000063)]
#
# Fake News CNN is looking at big management changes now that they got caught falsely pushing their phony Russian stories. Ratings way down!
#
# [(92, 0.35308564423935501), (17, 0.19163714048712033), (86, 0.11210133790333802), (19, 0.10709581945945477), (7, 0.065015049847759354), (66, 0.060823406561511861), (80, 0.058574934834794166)]
#
# Just spoke to President Macri of Argentina about the five proud and wonderful men killed in the West Side terror attack. God be with them!
#
# [(61, 0.23531097036534426), (44, 0.18636011219446041), (84, 0.13422322329454678), (30, 0.12815436621598811), (41, 0.097636182489654916), (10, 0.080105558299251534), (58, 0.080084587140754865)]
#
# North Korea has conducted a major Nuclear Test. Their words and actions continue to be very hostile and dangerous to the United States.....
#
# [(85, 0.29618122300005706), (83, 0.21500000000000019), (32, 0.2052473484285148), (31, 0.14357142857142871), (0, 0.072142857142857217)]
#
# Jay Sekulow on @foxandfriends now.
#
# [(30, 0.60200000000000176), (22, 0.2020000000000006)]
#
# Putin &amp; I discussed forming an impenetrable Cyber Security unit    so that election hacking, &amp; many other negative things, will be guarded..
#
# [(99, 0.45595659707844743), (46, 0.11888368269417768), (56, 0.11163060916106882), (23, 0.089020391222782741), (40, 0.083131983588637701), (69, 0.078710069588219675)]
#
# ISIS just claimed the Degenerate Animal who killed, and so badly wounded, the wonderful people on the West Side, was "their soldier." .....
#
# [(36, 0.33342831511378868), (29, 0.19703143581781146), (47, 0.13184799683121665), (75, 0.098703899706980833), (41, 0.0952369323056938), (97, 0.076608563081652356)]
#
# The North Korean regime has pursued its nuclear &amp; ballistic missile programs in defiance of every assurance, agreement, &amp; commmitment it has made to the U.S. and its allies. It's broken all of those commitments... https://t.co/xJ4jUpA8d8
#
# [(32, 0.21288782662306116), (63, 0.13570548511709846), (86, 0.12187321360092941), (83, 0.12110111041778876), (77, 0.081367367489130524), (41, 0.060492075225995305), (73, 0.058393925781770405), (67, 0.05788569140552792), (24, 0.057698390259515786), (20, 0.045226493026550026)]
#
# Welcome to the United States, @IsraeliPM Benjamin & Sara! #ICYMI🇺🇸🇮🇱Joint Press Conference:
#
# [(60, 0.81909090909090976), (42, 0.09181818181818191)]
#
# @CNN just released a book called "Unprecedented" which explores the 2016 race & victory. Hope it does well but used worst cover photo of me!
#
# [(63, 0.281784624594139), (88, 0.1344206650507494), (60, 0.10678642816494553), (22, 0.082753330205006803), (96, 0.068698961997218699), (40, 0.06842337577293163), (29, 0.067088241354583383), (5, 0.066991255185156695), (37, 0.066178117675269793)]
#
# The fact that President Putin and I discussed a Cyber Security unit  doesn't mean I think it can happen. It can't-but a ceasefire can,& did!
#
# [(99, 0.53693049378049151), (69, 0.16552144152726811), (77, 0.15412164856100574), (79, 0.074854987559806435)]
#
# Thank you Louisville, Kentucky- on my way! #MAGA🇺🇸
#
# [(74, 0.33500000000000069), (15, 0.17120478322321295), (35, 0.1683333333333337), (73, 0.16546188344345444)]
#
# Great listening session with CEO's of the Retail Industry Leaders Association this morning! https://t.co/sy6xJcWfcF
#
# [(63, 0.31105283498951403), (74, 0.24479549186208938), (77, 0.24475403651273289), (17, 0.10339763663566426)]
#
# The first meeting Jeff Sessions had with the Russian Amb was set up by the Obama Administration under education program for 100 Ambs......
#
# [(7, 0.16105468251657562), (19, 0.15461538461538482), (57, 0.15461538461538482), (36, 0.14817608671419402), (54, 0.14308246518171069), (3, 0.089225227125981979), (41, 0.077692307692307797)]
#
# Join me live as we recognize the first responders to the June 14th shooting involving @SteveScalise. #TeamScalise https://t.co/qOolNmB65d https://t.co/6OCn9JfMAG
#
# [(42, 0.1881984466896385), (78, 0.18815941029965189), (12, 0.18272727272727302), (19, 0.16936743213545793), (58, 0.094274710875252646), (21, 0.091818181818181965)]
#
# Happy #SmallBusinessSaturday!
#
# A great day to support your community and America’s JOB creators by shopping locally at a #SmallBiz. #ShopSmall https://t.co/pBQaBHvl7k
#
# [(28, 0.42928571428571671), (4, 0.2606431408813451), (81, 0.1238188404898847), (75, 0.11768087577162618)]
#
# Working hard on the biggest tax cut in U.S. history. Great support from so many sides. Big winners will be the middle class, business & JOBS
#
# [(68, 0.34406464243796248), (85, 0.15843640734821895), (87, 0.12605046441591017), (9, 0.099778340505592047), (15, 0.083125373905418298), (70, 0.082817311825938184), (34, 0.056780091139906959)]
#
# either elect more Republican Senators in 2018 or change the rules now to 51%. Our country needs a good "shutdown" in September to fix mess!
#
# [(97, 0.24996715697776367), (73, 0.17938749512516106), (2, 0.14930288273883341), (53, 0.12904933360012105), (15, 0.090759221143056415), (13, 0.081097805588637786), (80, 0.058436104826427755)]
#
# Isn't it sad that lightweight Senator Bob Corker, who couldn't get re-elected in the Great State of Tennessee, will now fight Tax Cuts plus!
#
# [(68, 0.3356646767441453), (7, 0.31408670641967423), (5, 0.12166053818980756), (36, 0.10258753499358954), (50, 0.070118190711604841)]
#
# My meetings with President Xi Jinping were very productive on both trade and the subject of North Korea. He is a highly respected and powerful representative of his people. It was great being with him and Madame Peng Liyuan!
#
# [(21, 0.37724075712071226), (42, 0.28409861936540753), (32, 0.18384981376707779), (85, 0.10147747641346833)]
#
# #USAatUNGA🇺🇸#UNGA
#
# [(30, 0.67000000000000315)]
#
# What is our country coming to when a judge can halt a Homeland Security travel ban and anyone, even with bad intentions, can come into U.S.?
#
# [(16, 0.81188276849219654), (69, 0.13047017268427208)]
#
# Insurance companies are fleeing ObamaCare - it is dead. Our healthcare plan will lower premiums & deductibles - and be great healthcare!
#
# [(65, 0.43065983676424219), (68, 0.34707914516297939), (35, 0.15297530351963692)]
#
# Thank you to Prime Minister of Australia for telling the truth about our very civil conversation that FAKE NEWS media lied about. Very nice!
#
# [(92, 0.29127427413323986), (76, 0.17935618826417279), (12, 0.16458301761131414), (27, 0.081687736416923687), (64, 0.072384497860064775), (16, 0.072142857142857245), (50, 0.072142857142857245)]
#
# Honored to meet this years @SenateYouth delegates w/ @VP Pence in the East Room of the @WhiteHouse. Congratulations… https://t.co/oQIx7LybCV
#
# [(42, 0.4464450677217095), (66, 0.19437203554181762), (39, 0.096201721724228376), (62, 0.094006280242812573), (36, 0.089808228102766091)]
#
# I will be at the @USGA #USWomensOpen in Bedminster, NJ tomorrow. Big crowds expected &amp; the women are playing great-should be very exciting!
#
# [(17, 0.35259299931464855), (75, 0.29379359610390465), (56, 0.12195708484250627), (43, 0.080887088969710849), (28, 0.077692307692307783)]
#
# James Comey will be replaced by someone who will do a far better job, bringing back the spirit and prestige of the FBI.
#
# [(79, 0.25834545129701103), (33, 0.19636706141319527), (95, 0.1676134500669515), (5, 0.14151221313289597), (2, 0.1007003356945278), (24, 0.072794821728752915)]
#
# 'Manufacturing openings, hires rise to highest levels of the recovery'
#
# [(48, 0.37625000000000047), (79, 0.25125000000000031), (50, 0.1262500000000002), (53, 0.12625000000000017)]
#
# Honored to meet this years @SenateYouth delegates w/ @VP Pence in the East Room of the @WhiteHouse. Congratulations…
#
# [(42, 0.4464977210189538), (66, 0.19446911026808691), (39, 0.096244745637710002), (62, 0.094048501655668457), (36, 0.089573254752915041)]
#
# RT @SLandinSoCal: @foxandfriends @realDonaldTrump Nothing can stop the #TrumpTrain‼️
#
# [(67, 0.34823275505657886), (94, 0.2489871772451665), (15, 0.15560547407601008), (77, 0.12717459362224509)]
#
# "Dow Passes 23,000 for the First Time, Fueled by Strong Earnings" #Dow23K📈
#
# [(78, 0.26475095525627501), (73, 0.22333333333333372), (3, 0.1588950448020246), (52, 0.13524288883059019), (23, 0.1122222222222224)]
#
# Thank you for the great rallies all across the country. Tremendous support. Make America Great Again!
#
# [(75, 0.47103942090923911), (81, 0.30801354650053481), (97, 0.13276521440840827)]
#
# The forgotten men and women of our country will be forgotten no longer. From this moment on, it’s going to be #AmericaFirst🇺🇸
#
# [(51, 0.54769095609604068), (30, 0.24477730920583998), (40, 0.11934991651630229)]
#
# RT @seanhannity: #Hannity Starts in 30 minutes with @newtgingrich and my monologue on the Deep State’s allies in the media
#
# [(11, 0.72526250266791514), (56, 0.094737497332086335), (92, 0.091818181818181993)]
#
# Karen Handle's opponent in #GA06 can't even vote in the district he wants to represent....
#
# [(97, 0.90100000000000002)]
#
# Thank you!   “Trump’s Defining Speech”  WSJ Editorial:
#
# [(49, 0.43000000000000083), (30, 0.2871428571428577), (61, 0.14428571428571454)]
#
# It was a great privilege to meet with President Moon of South Korea. Stay tuned! 🇺🇸🇰🇷#UNGA
#
# [(52, 0.50551224698623454), (30, 0.11796187533430356), (3, 0.10280437661205417), (80, 0.095337829200926164), (57, 0.092020035502846501)]
#
# The opinion of this so-called judge, which essentially takes law-enforcement away from our country, is ridiculous and will be overturned!
#
# [(6, 0.4959398811515624), (54, 0.25567845760365016), (40, 0.17376627662940422)]
#
# Democrats jeopardizing the safety of our troops to bail out their donors from insurance companies. It is time to put #AmericaFirst🇺🇸
#
# [(65, 0.37435531434244279), (25, 0.24884181210944281), (16, 0.10808083365022508), (3, 0.098291779422327655), (8, 0.091263593808896371)]
#
# BORDER WALL prototypes underway!
#
# [(22, 0.54904939245871665), (82, 0.2549506075412859)]
#
# RT @foxandfriends: FOX NEWS ALERT: 2 US drone strikes in Somalia target Al Qaeda and Al-Shabaab https://t.co/MqrY7zbMy2
#
# [(57, 0.65394293119315916), (37, 0.14118472911462149), (78, 0.11669052151040209)]
#
# Ratings for NFL football are way down except before game starts, when people tune in to see whether or not our country will be disrespected!
#
# [(11, 0.34384125435338198), (73, 0.19994467371367156), (74, 0.1641622697552178), (50, 0.13823760155490947), (53, 0.090480867289486913)]
#
# CHAIN MIGRATION cannot be allowed to be part of any legislation on Immigration!
#
# [(53, 0.28714285714285753), (94, 0.28714285714285753), (52, 0.14428571428571449), (28, 0.14428571428571446)]
#
# Thank you to Ford for scrapping a new plant in Mexico and creating 700 new jobs in the U.S. This is just the beginning - much more to follow
#
# [(85, 0.33369709079136539), (28, 0.23552292442196698), (24, 0.19380131945702758), (72, 0.089856852444280835), (18, 0.083788479550138337)]
#
# It is amazing how rude much of the media is to my very hard working representatives. Be nice, you will do much better!
#
# [(24, 0.48308570346785068), (76, 0.24233991149983161), (6, 0.19374105169898587)]
#
# Getting ready to engage G7 leaders on many issues including economic growth, terrorism, and security.
#
# [(67, 0.30315598212899919), (88, 0.19439615610865127), (69, 0.15654777666273378), (41, 0.095118890003933115), (16, 0.094954415702338105), (44, 0.077493446060012003)]
#
# All of my Cabinet nominee are looking good and doing a great job. I want them to be themselves and express their own thoughts, not mine!
#
# [(38, 0.32426320481899545), (2, 0.18858127381000045), (65, 0.15354526829606346), (78, 0.14844983407984896), (97, 0.098796782631457011)]
#
# Inauguration Day is turning out to be even bigger than expected. January 20th, Washington D.C. Have fun!
#
# [(60, 0.27363636363636379), (88, 0.25989988887184345), (75, 0.18272727272727282), (80, 0.1055546565827022), (0, 0.091818181818181882)]
#
# ...(enthusiastic, dynamic and fun) and the American Legion - V.A. (respectful and strong).To bad the Dems have no one who can change tones!
#
# [(80, 0.73400000000000043), (61, 0.20066666666457952)]
#
# Had a great meeting at CIA Headquarters yesterday, packed house, paid great respect to Wall, long standing ovations, amazing people. WIN!
#
# [(54, 0.21099119562238355), (11, 0.20116809851662726), (10, 0.17463498770362598), (6, 0.13393648981415243), (34, 0.082586931942899094), (60, 0.079925238610970561), (20, 0.065090391122671371)]
#
# Many people booed the players who kneeled yesterday (which was a small percentage of total). These are fans who demand respect for our Flag!
#
# [(11, 0.41423912100841154), (52, 0.30885290265929177), (34, 0.13130513835442204), (69, 0.077031409406447163)]
#
# May God Forever Bless the United States of America. #NeverForget911
#
# [(27, 0.23318551699363887), (14, 0.22333333333325273), (26, 0.11222222222222247), (28, 0.11222222222222245), (68, 0.11222222222222245), (81, 0.10237003856191731)]
#
# RT @ProgressPolls: Who is a better President of the United States? #ObamaDay
#
# [(82, 0.85857142564192157)]
#
# The #AmazonWashingtonPost, sometimes referred to as the guardian of Amazon not paying internet taxes (which they should) is FAKE NEWS!
#
# [(32, 0.45545454545454611), (92, 0.18272727272727435), (91, 0.10380716778207055), (20, 0.091818181818180564), (68, 0.079829195854293364)]
#
# A NEW ERA IN AMERICAN ENERGY!  #MadeInTheUSA🇺🇸 Watch here:
#
# [(4, 0.30331869426802288), (49, 0.2988059743598091), (27, 0.14428571428571471), (28, 0.11644675994359853)]
#
# Many people booed the players who kneeled yesterday (which was a small percentage of total). These are fans who demand respect for our Flag!
#
# [(11, 0.41410177655657376), (52, 0.308821356708401), (34, 0.13147753142175259), (69, 0.077027906741845328)]
#
# RT @foxandfriends: Head of the NYPD union slams Mayor de Blasio for skipping vigil for assassinated cop Miosotis Familia https://t.co/nVWLb…
#
# [(1, 0.64357142857142957), (28, 0.14357142857142877), (83, 0.072142857142857258), (69, 0.072142857142857231)]
#
# Sleazy Adam Schiff, the totally biased Congressman looking into "Russia," spends all of his time on television pushing the Dem loss excuse!
#
# [(5, 0.48609017658952453), (17, 0.18042596920685156), (19, 0.14042237499552154), (25, 0.13306147920810363)]
#
# Getting ready to leave for Poland, after which I will travel to Germany for the G-20. Will be back on Saturday.
#
# [(31, 0.33232386716608464), (79, 0.22618245986805405), (48, 0.12493098189324278), (88, 0.11566312501490923), (91, 0.11453592969384704)]
#
# If @RepMarkMeadows, @Jim_Jordan and Raul_Labrador would get on board we would have both great healthcare and massive tax cuts & reform.
#
# [(68, 0.45738706217210934), (66, 0.36974777548820437), (67, 0.092031829006352428)]
#
# RT @jayMAGA45: NFLplayer PatTillman joined U.S. Army in 2002. He was killed in action 2004. He fought 4our country/freedom. #StandForOurAnt…
#
# [(33, 0.21239517736071661), (4, 0.16191729030384358), (19, 0.16076304168867925), (58, 0.14866895780500253), (72, 0.13683272262096347), (64, 0.10711511791310376)]
#
# Miami-Dade Mayor drops sanctuary policy. Right decision. Strong!
#
# [(74, 0.4890508455135818), (26, 0.20100000000000029), (38, 0.11294915448641916), (83, 0.10100000000000015)]
#
# Democrats jeopardizing the safety of our troops to bail out their donors from insurance companies. It is time to put #AmericaFirst🇺🇸
#
# [(65, 0.37433588680939778), (25, 0.24870421418205504), (16, 0.10827474487815299), (3, 0.09826804860649388), (8, 0.091250438857235008)]
#
# RT @foxandfriends: "Yesterday's hearings provided zero evidence of collusion between our campaign and the Russians because there wasn't any…
#
# [(56, 0.48946507507502979), (45, 0.18666397377137645), (27, 0.13080985754521005), (19, 0.097061093608385191)]
#
# HAPPY 70th BIRTHDAY to the @USAirForce! The American people are eternally grateful. Thank you for keeping America PROUD, STRONG and FREE! https://t.co/DYxkh3gj0R
#
# [(46, 0.34631049104416245), (17, 0.28619901401705444), (62, 0.12931325905282587), (78, 0.098549267386018852), (81, 0.071770825642796757)]
#
# I am watching the Democrats trying to defend the "you can keep you doctor, you can keep your plan & premiums will go down" ObamaCare lie."
#
# [(69, 0.33207889052645501), (65, 0.27548012032904157), (77, 0.1399368913182143), (32, 0.11644963562043652), (27, 0.072721128872520122)]
#
# Big announcement by Ford today. Major investment to be made in three Michigan plants. Car companies coming back to U.S.  JOBS! JOBS! JOBS!
#
# [(85, 0.309043812276246), (83, 0.22058514059958495), (79, 0.20361627627137327), (13, 0.10936246612513985), (35, 0.05401165697415599), (31, 0.053906963542973238)]
#
# Thr coverage about me in the @nytimes and the @washingtonpost gas been so false and angry that the times actually apologized to its.....
#
# [(25, 0.31018340682484136), (19, 0.28898338731070616), (58, 0.11602278012061985), (27, 0.10662860756201567), (30, 0.091818181818181938)]
#
# RT @IvankaTrump: I have long respected India's accomplished and charismatic Foreign Minister @SushmaSwaraj, and it was an honor to meet her…
#
# [(57, 0.25083333333333363), (42, 0.22348664681216213), (38, 0.1675000000000002), (12, 0.15347689448861757), (96, 0.12553645869922095)]
#
# The ABC/Washington Post Poll, even though almost 40% is not bad at this time, was just about the most inaccurate poll around election time!
#
# [(38, 0.42848612882272047), (86, 0.33743680252175856), (27, 0.087144436761573907), (59, 0.086932631893947732)]
#
# RT @DonaldJTrumpJr: Happy new year everyone. #newyear #family #vacation #familytime
#
# [(17, 0.32163407789866122), (66, 0.26112790418838344), (28, 0.17500167810399198), (75, 0.14623633980896492)]
#
# RT @GOP: .@IvankaTrump: This administration is committed to keeping working families at the forefront of our agenda.
#
# [(47, 0.564633993533319), (96, 0.3373660064666818)]
#
# No deal was made last night on DACA. Massive border security would have to be agreed to in exchange for consent. Would be subject to vote.
#
# [(34, 0.26196333019074935), (0, 0.18328096519142859), (85, 0.17667267353890656), (29, 0.096027299020214535), (38, 0.088977602364276251), (69, 0.069970678289089053), (82, 0.0566788799767656)]
#
# So now it is reported that the Democrats, who have excoriated Carter Page about Russia, don't want him to testify. He blows away their....
#
# [(4, 0.75083333333333457), (65, 0.16750000000000032)]
#
# Just out: The same Russian Ambassador that met Jeff Sessions visited the Obama White House 22 times, and 4 times last year alone.
#
# [(58, 0.61961347441556147), (54, 0.12976323198260095), (0, 0.12562500000000015), (19, 0.064998293601838619)]
#
# We are making great progress with healthcare. ObamaCare is imploding and will only get worse. Republicans coming together to get job done!
#
# [(87, 0.25323912187248537), (68, 0.21823203952277204), (2, 0.21394404852073676), (73, 0.18885658106253461), (34, 0.066353209021472376)]
#
# Thanks for your support!
#
# [(22, 0.67000000000000359)]
#
# Working on major Trade Deal with the United Kingdom. Could be very big &amp; exciting. JOBS! The E.U. is very protectionist with the U.S. STOP!
#
# [(85, 0.62906913881505822), (76, 0.15264777173994121), (93, 0.14899737515928649)]
#
# Getting ready for my big foreign trip. Will be strongly protecting American interests - that's what I like to do!
#
# [(31, 0.22634611634347757), (50, 0.2041592967203259), (44, 0.19551418405660909), (88, 0.15734021560826342), (57, 0.13747352060465837)]
#
# We want to make sure that we have the workforce development programs we need to ensure these jobs are.... https://t.co/tyqbvvmBn4
#
# [(82, 0.28496426075651288), (83, 0.18976962382026191), (49, 0.17784240726719547), (70, 0.13604069129852847), (81, 0.11638301663456424)]
#
# The state of Virginia economy, under Democrat rule, has been terrible. If you vote Ed Gillespie tomorrow, it will come roaring back!
#
# [(6, 0.37301597690609195), (79, 0.2042511481022585), (56, 0.1777269096430994), (38, 0.10500596534805594), (93, 0.072142857143352612)]
#
# The United States is considering, in addition to other options, stopping all trade with any country doing business with North Korea.
#
# [(32, 0.29592885630504345), (85, 0.26926690529985564), (29, 0.1825282436842629), (7, 0.088942661377505589), (94, 0.084166666666666765)]
#
# Playing golf with Prime Minister Abe and Hideki Matsuyama, two wonderful people! https://t.co/vYLULe0o2K
#
# [(29, 0.51735435605138413), (12, 0.3935547348577082)]
#
# Thank you to the GREAT NYPD, First Responders and all govt officials for having handled the terrible West Side attack so professionally! https://t.co/imPIdOzjAn
#
# [(51, 0.40164694279213436), (61, 0.35782518020611109), (64, 0.099813591287469375), (40, 0.072142857142857189)]
#
# RT @TuckerCarlson: .@RichardGrenell : @realDonaldTrump told Tillerson he had the full support of the U.S. Gov't to bring #OttoWarmbier home…
#
# [(80, 0.36767506678816597), (79, 0.23153846153846164), (70, 0.16571272291820563), (24, 0.084304517985936397), (65, 0.077692307692307741)]
#
# "Puerto Rico survived the Hurricanes, now a financial crisis looms largely of their own making." says Sharyl Attkisson. A total lack of.....
#
# [(62, 0.52895224353981285), (75, 0.18815905941320255), (25, 0.096482221761959308), (35, 0.070046346194425915), (81, 0.056985129090600176)]
#
# Beautiful evening with Religious Leaders here at the WH last night. Join us now for a #NationalDayofPrayer, LIVE:… https://t.co/b8j1tWZJuv
#
# [(6, 0.34723694126736354), (19, 0.19351274828587439), (0, 0.16497123899896804), (77, 0.10660909207893583), (60, 0.10130634300522337)]
#
# I will be interviewed on @foxandfriends at 6:00 A.M. Enjoy!
#
# [(56, 0.80199999821623302)]
#
# ...to Mar-a-Lago 3 nights in a row around New Year's Eve, and insisted on joining me. She was bleeding badly from a face-lift. I said no!
#
# [(74, 0.50062500000095977), (87, 0.12562500000000013), (0, 0.098747398839915151), (20, 0.090002601159125811), (28, 0.06312500000000007), (19, 0.063125000000000056)]
#
# Spoke at the Congressional @GOP Retreat in Philadelphia, PA. this afternoon w/ @VP, @SenateMajLdr, @SpeakerRyan. Th…
#
# [(47, 0.90100000000000091)]
#
# RT @FoxNews: TUNE IN: @EricTrump joins @seanhannity TONIGHT at 9p ET on @FoxNews Channel! #Hannityat9
#
# [(56, 0.40100000000000074), (7, 0.20100000000000037), (17, 0.1010000000000002), (19, 0.1010000000000002), (57, 0.1010000000000002)]
#
# The G 20 Summit was a great success for the U.S. - Explained that the U.S. must fix the many bad trade deals it has made. Will get done!
#
# [(85, 0.37240192259620652), (64, 0.21044936950386364), (34, 0.14470271659418918), (82, 0.14448939437485744), (33, 0.072074243989706119)]
#
# Two dozen NFL players continue to kneel during the National Anthem, showing total disrespect to our Flag & Country.  No leadership in NFL!
#
# [(11, 0.59874640267491885), (25, 0.13789801884681749), (4, 0.06929559040475973), (46, 0.067823019413491101), (22, 0.06686196866001376)]
#
# Throughout my travels, I've had the pleasure of sharing the good news from America. I've had the honor of sharing our vision for a free & open Indo-Pacific -- a place where sovereign & independent nations, w/diverse cultures & many different dreams, can all prosper side-by-side.
#
# [(70, 0.33886454660425913), (45, 0.14951356280038686), (49, 0.13171734769110821), (4, 0.11804758863450597), (16, 0.073279855549646639), (77, 0.072084492233755335), (61, 0.046585020128825198), (50, 0.037050443500368298)]
#
# ...
#
# Prosperity is coming back to our shores because we are putting America WORKERS and FAMILIES first. #AmericaFirst🇺🇸 https://t.co/4kTc6Om308
#
# [(20, 0.24898326912032542), (87, 0.23560432752775254), (25, 0.23528837075094541), (40, 0.098190798988635863), (79, 0.095569597248705701)]
#
# We will fight the #FakeNews with you! https://t.co/zOMiXTeLJq
#
# [(9, 0.50250000000000239), (99, 0.25250000000000122)]
#
# The @USNavy is conducting search and rescue following aircraft crash. We are monitoring the situation. Prayers for all involved.
#
# [(97, 0.24241971206981175), (65, 0.16750000000000015), (61, 0.092580287930188576), (34, 0.084166666666666778), (30, 0.084166666666666751), (35, 0.084166666666666751), (58, 0.084166666666666751), (85, 0.084166666666666751)]
#
# Today, we continued a wonderful American Tradition at the White House. Drumstick and Wishbone will live out their days in the beautiful Blue Ridge Mountains at Gobbler’s Rest... https://t.co/fsS8B8f5UR
#
# [(26, 0.4773927790035179), (54, 0.16896914339822322), (12, 0.11758631009793381), (73, 0.10064941501895061), (19, 0.085402352481371444)]
#
# Will be having many meetings this weekend at The Southern White House. Big 5:00 P.M. speech in Melbourne, Florida. A lot to talk about!
#
# [(98, 0.56300222279694812), (54, 0.36699777720305249)]
#
# The Failing New York Times foiled U.S. attempt to kill the single most wanted terrorist,Al-Baghdadi.Their sick agenda over National Security
#
# [(28, 0.24992037027730621), (58, 0.18055385159245854), (88, 0.10840225173137331), (30, 0.10629577932469988), (29, 0.098076340561748562), (52, 0.095084739845054819), (93, 0.084166666667359682)]
#
# Thank you for a wonderful evening in Washington, D.C. #Inauguration
#
# [(12, 0.37613479756359675), (38, 0.25130355914127833), (0, 0.23399021472369855)]
#
# RT @DiamondandSilk: When the President says "You're Fired"     That means: "Pack Yo Stuff and Go, Not Say "You Refuse to Go!  #DrainTheSwam…
#
# [(45, 0.91000000000000081)]
#
# I will be going to Puerto Rico on Tuesday with Melania. Will hopefully be able to stop at the U.S. Virgin Islands (people working hard).
#
# [(2, 0.17582396403085321), (76, 0.15671116540351449), (10, 0.14960134695622826), (65, 0.14252826937339458), (84, 0.13891445351688381), (15, 0.12961723185788251), (42, 0.052097686508301523)]
#
# The American people have waited long enough. There has been enough talk and no action for seven years. Now is the time for action! https://t.co/VdTiYL0Ua7
#
# [(4, 0.50592467911754557), (2, 0.25199668885559939), (16, 0.17279291774114214)]
#
# RT @Team_Trump45: @realDonaldTrump
#
# [(12, 0.67000000000000415)]
#
# Nick Adams new book, Green Card Warrior, is a must read. The merit-based system is the way to go. Canada, Australia! @foxandfriends
#
# [(12, 0.32994619575291234), (37, 0.30151536891005137), (41, 0.15597496659709928), (28, 0.089181587960993736), (49, 0.067499527837762877)]
#
# Spoke yesterday with the King of Saudi Arabia about peace in the Middle-East. Interesting things are happening!
#
# [(99, 0.33419882377046412), (16, 0.23880516647859579), (39, 0.16750000000000023), (79, 0.096162676417607687), (50, 0.084166666666666792)]
#
# Thank you to all of the men and women who protect &amp; serve our communities 24/7/365!
# #LawEnforcementAppreciationDay… https://t.co/aqUbDipSgv
#
# [(91, 0.55372619348931063), (17, 0.32377380651069132)]
#
# ....This is real collusion and dishonesty. Major violation of Campaign Finance Laws and Money Laundering - where is our Justice Department?
#
# [(94, 0.31997458128707867), (30, 0.29730442121271411), (31, 0.15205647080073617), (45, 0.079895295930241181), (7, 0.077692307692307783)]
#
# The @NBCNews story has just been totally refuted by Sec. Tillerson and @VP Pence. It is #FakeNews. They should issue an apology to AMERICA!
#
# [(92, 0.24431091823359796), (27, 0.16817918679322486), (66, 0.13968767197264023), (67, 0.085721858659165401), (64, 0.078773354996976921), (73, 0.076177584277117766), (24, 0.072142857142857203), (81, 0.069292282210134837)]
#
# JOBS, JOBS, JOBS! #MAGA🇺🇸
#
# [(78, 0.60200000000000053), (74, 0.20200000000000012)]
#
# RT @DRUDGE_REPORT: RICE ORDERED SPY DOCS ON TRUMP? https://t.co/bL2nZRFxk9
#
# [(48, 0.71007197702206937), (21, 0.14992802296640542)]
#
# Major rescue operations underway!
#
# [(22, 0.27594351690128244), (61, 0.2020000000000006), (86, 0.20200000000000054), (31, 0.12805648309871864)]
#
# Big win in the House - very exciting! But when everything comes together with the inclusion of Phase 2, we will have truly great healthcare!
#
# [(98, 0.26421698205275645), (87, 0.23042291683784977), (54, 0.10526072734517077), (68, 0.090149596033479426), (99, 0.086047979765721344), (57, 0.08263415196459141), (43, 0.074839074571860023)]
#
# Congratulation to Roy Moore and Luther Strange for being the final two and heading into a September runoff in Alabama. Exciting race!
#
# [(11, 0.37973623456308259), (78, 0.1778702546763887), (13, 0.15882208218910104), (4, 0.14204460765425483), (43, 0.073669678060031191)]
#
# I will be announcing my decision on the Paris Accord over the next few days. MAKE AMERICA GREAT AGAIN!
#
# [(36, 0.32223429062814568), (99, 0.30262285777389558), (81, 0.2869610334161416)]
#
# Publicity seeking Lindsey Graham falsely stated that I said there is moral equivalency between the KKK, neo-Nazis & white supremacists......
#
# [(54, 0.41946553699228989), (40, 0.29976249153542023), (25, 0.11747883042700563), (36, 0.099293141045285194)]
#
# Thank you @SenatorDole, very kind! https://t.co/cXrYiK46Qq
#
# [(1, 0.75249999999993533)]
#
# The super Liberal Democrat in the Georgia Congressioal race tomorrow wants to protect criminals, allow illegal immigration and raise taxes!
#
# [(44, 0.35209746525315411), (82, 0.17411733443075089), (96, 0.11545612313489213), (94, 0.11366936059500686), (23, 0.099753611854685467), (26, 0.086156104731511418)]
#
# The Democrats, lead by head clown Chuck Schumer, know how bad ObamaCare is and what a mess they are in. Instead of working to fix it, they..
#
# [(65, 0.31965332650792505), (31, 0.16206619977449227), (76, 0.13560297393380469), (15, 0.10044940229255278), (38, 0.086055830827317117), (24, 0.077506591113386161), (82, 0.052237104121951553)]
#
# RT @FoxNews: .@KellyannePolls on Harvey recovery: We hope when it comes to basic Hurricane Harvey funding that we can rely upon a nonpartis…
#
# [(60, 0.53400000000000036), (77, 0.13400000000000004), (79, 0.13193002941472606), (5, 0.069403303918607356), (56, 0.06733333333333337)]
#
# Remember when the failing @nytimes apologized to its subscribers, right after the election, because their coverage was so wrong. Now worse!
#
# [(27, 0.25924467395291789), (88, 0.20325378899920779), (70, 0.10336777596718293), (73, 0.10222311842715255), (20, 0.089096924561790608), (87, 0.084166666666666792), (1, 0.081147051425077943)]
#
# Maybe the millions of people who voted to MAKE AMERICA GREAT AGAIN should have their own rally. It would be the biggest of them all!
#
# [(52, 0.42927412548036525), (81, 0.27111288802496464), (49, 0.10209837587089343), (76, 0.10151461062377742)]
#
# The Russia-Trump collusion story is a total hoax, when will this taxpayer funded charade end?
#
# [(27, 0.9175000000000012)]
#
# Border Patrol Officer killed at Southern Border, another badly hurt. We will seek out and bring to justice those responsible. We will, and must, build the Wall!
#
# [(79, 0.1829308124152188), (20, 0.14593352236170976), (98, 0.11818866948032108), (17, 0.10578947368421046), (76, 0.10307303965918888), (82, 0.097188332392909693), (52, 0.071919238911024905), (59, 0.065074690720944434), (1, 0.062007483532366153)]
#
# Just landed in the Philippines after a great day of meetings and events in Hanoi, Vietnam!
#
# [(51, 0.9009999999999988)]
#
# Presidential Memorandum for the @CommerceGov, @SecretaryRoss re: Aluminum Imports and Threats to National Security:…
#
# [(14, 0.40099999995908792), (26, 0.30100000000000049), (5, 0.10100000000000019), (34, 0.10100000000000019)]
#
# We stand in absolute solidarity with the people of the United Kingdom.
#
# [(93, 0.57285714272995192), (11, 0.28714285696825648)]
#
# Very proud of our incredible First Lady (@FLOTUS.) She is a truly great representative for our country! https://t.co/yFv0WIjgby
#
# [(99, 0.29446327901961056), (22, 0.24464943062320071), (10, 0.24292518684309225), (33, 0.12196210351409799)]
#
# ...The fact is that Puerto Rico has been destroyed by two hurricanes. Big decisions will have to be made as to the cost of its rebuilding!
#
# [(36, 0.20553079636527297), (65, 0.15894502112295791), (71, 0.14224606028129874), (32, 0.12017891518431084), (17, 0.1158106007545627), (93, 0.10396931320011511), (4, 0.08178083155302128)]
#
# ...(enthusiastic, dynamic and fun) and the American Legion - V.A. (respectful and strong).To bad the Dems have no one who can change tones!
#
# [(80, 0.73400000000000043), (61, 0.20066666666666677)]
#
# RT @LouDobbs: #AmericaFirst- @KellyannePolls: The Middle Class & businesses will benefit from @POTUS' historic tax revolution. #Dobbs #MAGA…
#
# [(77, 0.32189946856794649), (87, 0.19175524076488343), (21, 0.18706335574058322), (2, 0.093100258507856262), (44, 0.077426088999416956), (68, 0.066088920752647926)]
#
# RT @DanScavino: 'Trump as Commander in Chief, Making the Hard Decisions' by LTG (Ret) Kellogg, a highly decorated Vietnam War Vet:
#
# [(3, 0.46683625086293756), (8, 0.17343744157589919), (81, 0.15113083936362648), (17, 0.082871598161480278), (36, 0.066348870036057564)]
#
# The devastation left by Hurricane Irma was far greater, at least in certain locations,than anyone thought - but amazing people working hard!
#
# [(90, 0.51876499572964285), (31, 0.2649643128494189), (98, 0.080504681616148349), (10, 0.075766009804790702)]
#
# We're going to use American steel, we're going to use American labor, we are going to come first in all deals. ➡️…
#
# [(14, 0.32732136501342063), (76, 0.26103363552475739), (26, 0.25434575552427752), (87, 0.083453090091391791)]
#
# Would very much appreciate Saudi Arabia doing their IPO of Aramco with the New York Stock Exchange. Important to the United States!
#
# [(99, 0.42107595377825707), (24, 0.16550392893430571), (18, 0.160454352545114), (28, 0.10638020551228182), (86, 0.078728416372899748)]
#
# The White House never looked more beautiful than it did returning last night. Important meetings taking place today. Big tax cuts & reform.
#
# [(26, 0.27580454181904329), (68, 0.23369238546609583), (54, 0.19004945483033434), (0, 0.18733588453596681), (74, 0.060339955570780229)]
#
# Just landed in Paris, France with @FLOTUS Melania. https://t.co/knULGOQF1K
#
# [(10, 0.43000000000000127), (4, 0.43000000000000121)]
#
# What about all of the contact with the Clinton campaign and the Russians? Also, is it true that the DNC would not let the FBI in to look?
#
# [(58, 0.44131608317391496), (59, 0.26596595090541686), (55, 0.10433412966635633), (27, 0.10111110898158522)]
#
# Such amazing reporting on unmasking and the crooked scheme against us by @foxandfriends. "Spied on before nomination." The real story.
#
# [(51, 0.19606542804006349), (13, 0.18272727270931852), (17, 0.17626654162592645), (92, 0.15995758677008012), (22, 0.10124971246258431), (48, 0.098278912919528463)]
#
# ...Save your energy Rex, we'll do what has to be done!
#
# [(16, 0.3745641380245579), (64, 0.28801419256805266), (77, 0.14342166940739218)]
#
# The crackdown on illegal criminals is merely the keeping of my campaign promise. Gang members, drug dealers &amp; others are being removed!
#
# [(55, 0.57214285714285751), (69, 0.25666806151189092), (23, 0.10190336705953792)]
#
# The world is noticing, thanks! https://t.co/2NL6SlWnmH
#
# [(30, 0.49087737322355873), (98, 0.26412262677644394)]
#
# Crazy Joe Scarborough and dumb as a rock Mika are not bad people, but their low rated show is dominated by their NBC bosses. Too bad!
#
# [(80, 0.48972268888088211), (86, 0.19824178129691417), (93, 0.12490444383841104), (76, 0.064631085983792899), (17, 0.063125000000000014)]
#
# When James Clapper himself, and virtually everyone else with knowledge of the witch hunt, says there is no collusion, when does it end?
#
# [(4, 0.25083333333333374), (45, 0.25083333333333291), (19, 0.16750000000000029), (37, 0.08416666666666682), (52, 0.08416666666666682), (60, 0.08416666666666682)]
#
# Prime Minister @Netanyahu and @PresidentRuvi- on behalf of @FLOTUS Melania and myself, thank you for the invitation… https://t.co/Z5YCpaRV6t
#
# [(10, 0.26979989113917063), (12, 0.22896181040720692), (90, 0.10423829688892521), (7, 0.10100000156469859), (62, 0.10100000000000021), (45, 0.10100000000000017)]
#
# Does anyone notice how the Montana Congressional race was such a big deal to Dems &amp; Fake News until the Republican won? V was poorly covered
#
# [(98, 0.79987802200335612), (92, 0.1347886446633105)]
#
# RT @Scavino45: Hurricane force winds hit Florida Keys. 390 shelters have been opened in Florida. Shelters near you➡️
#
# [(50, 0.62067308001051691), (55, 0.20488664951441732), (71, 0.099824885859681842)]
#
# HAPPY PRESIDENTS DAY - MAKE AMERICA GREAT AGAIN!
#
# [(81, 0.42834366666322254), (4, 0.2825067085605526), (71, 0.15057819620479868)]
#
# Storm turned Hurricane is getting much bigger and more powerful than projected. Federal Government is on site and ready to respond. Be safe!
#
# [(88, 0.93400000000000005)]
#
# Sadly, they and others are Fake News, and the public is just beginning to figure it out! https://t.co/8B8AyA7V1s
#
# [(90, 0.40083105863612345), (92, 0.261181211704966), (36, 0.11909884077002275), (7, 0.11222222222222235)]
#
# RT @GOPChairwoman: The Trump Inaugural Committee is donating $3 million in surplus funds to victims of the latest hurricanes.
# https://t.co…
#
# [(60, 0.31420528387188534), (3, 0.17185223812187531), (8, 0.15335332582392824), (76, 0.1052884601900036), (59, 0.089307349456220667), (85, 0.087660009202755115)]
#
# I have tremendous respect for women and the many roles they serve that are vital to the fabric of our society and our economy.
#
# [(77, 0.72818181818181937), (17, 0.18272727272727302)]
#
# Honored to sign S.442 today. With this legislation, we support @NASA's scientists, engineers, and astronauts in the… https://t.co/Z5VwluvJQx
#
# [(56, 0.50069528126446217), (70, 0.2352928739467334), (28, 0.09181818181818191), (42, 0.084920935697896147)]
#
# RT @foxandfriends: Israeli PM Netanyahu praises U.S. policy changes during meeting with Defense. Sec Mattis
#
# [(97, 0.82905599852821921), (80, 0.089277334805114253)]
#
# Thanks for your support! https://t.co/iqUM1RfQso
#
# [(22, 0.67000000000000359)]
#
# Big announcement by Ford today. Major investment to be made in three Michigan plants. Car companies coming back to U.S.  JOBS! JOBS! JOBS!
#
# [(85, 0.30878189264340405), (83, 0.22119101908732644), (79, 0.20612685985868626), (24, 0.06957883694392096), (13, 0.066913466272030736), (65, 0.041299853435008534), (31, 0.037160703338569807)]
#
# Russia just said the unverified report paid for by political opponents is "A COMPLETE AND TOTAL FABRICATION, UTTER NONSENSE." Very unfair!
#
# [(5, 0.72693394795703725), (29, 0.12808682807901717), (74, 0.080312557297280152)]
#
# Will be doing a joint press conference in Hanoi, Vietnam then heading for final destination of trip, the Phillipines.
#
# [(60, 0.41749999996465587), (51, 0.23381061938727027), (63, 0.095663490317548408), (38, 0.089692556713756588), (58, 0.084166666666666737)]
#
# Beautiful evening with Religious Leaders here at the WH last night. Join us now for a #NationalDayofPrayer, LIVE:…
#
# [(6, 0.33660380192697648), (19, 0.20014407386899843), (0, 0.16679653163256236), (67, 0.12414262421831293), (60, 0.085949331989514988)]
#
# Just landed in the Philippines after a great day of meetings and events in Hanoi, Vietnam!
#
# [(51, 0.90099999901816497)]
#
# Republicans must be careful in that the Dems own the failed ObamaCare disaster, with its poor coverage and massive premium increases......
#
# [(65, 0.23153846153846183), (41, 0.18836446163368031), (88, 0.1546153845545222), (53, 0.10716677863196777), (20, 0.097246693230848308), (70, 0.077692307692307783), (15, 0.071837451179751446)]

# %%
clusters = [max(lda[tweet], key=lambda tup: tup[1]) for tweet in ltest if len(tweet) > 0]

# %%
w = [1 / len(clusters)] * len(clusters)
pd.Series([c[0] for c in clusters]).hist(bins=100, weights=w)

# %%
dfTest = pd.DataFrame(columns=['Max Topic', 'Text'])
orig_test.index = range(len(orig_test))
dfTest['Max Topic'] = [c[0] for c in clusters]
dfTest['Text'] = [orig_test[i] for i in range(len(orig_test)) if len(ltest[i]) > 0]

# %%
def testTopic(dfTest, i):
    group = dfTest[dfTest['Max Topic'] == i]['Text']
    group.apply(lambda x: print(x, "\n"))
    print("frequency:", len(group) / len(dfTest) * 100, "%")

# 98: media are biased
# 95: addressing Marco Rubio
# 1: Ted Cruz
# 2: ?
# 3: War, violence, terrorism, nuclear power..
# 4: Showing off Endorsements
# 5: ?
# 6: Team empowerement?
# 7: Trump Family is great
# 8: Cheating crooked hilary
# 9: Talking about fundings
# 10: Trump fights for people
# 11: ? Media 
# 12: Addressing workers
# 13: Trump president-elect
# 14: Trump "spreading the TRUTH"
# 15: Trump will win, the others will lose
# 16: All talk no action
# 17: Trump announces relocating
# 18: ? Nevada and Cruz again
# 19: ? Media?
# 20: Islamic terrorism ban
# 21: Trump thanking after rally
# 22: ? Hilary
# 23: Brexit
# 24: Discussing polls
# 25: Announcing interview
# 26: ? People supporting Trump
# 27: ?
# 28
# 32: Wishing
# 
testTopic(dfTest, 10)
# Out:
# ...vast sums of money to NATO &amp; the United States must be paid more for the powerful, and very expensive, defense it provides to Germany!
#
# ...people are now starting to recognize the amazing work that has been done by FEMA and our great Military. All buildings now inspected.....
#
# Prime Minister @Netanyahu and @PresidentRuvi- on behalf of @FLOTUS Melania and myself, thank you for the invitation…
#
# Wishing @FLOTUS Melania and all of the great mothers out there a wonderful day ahead with family and friends!   Happy #MothersDay
#
# The Democrats have no message,  not on economics, not on taxes,  not on jobs, not on failing #Obamacare. They are only OBSTRUCTIONISTS!
#
# President Donald J. Trump and @FLOTUS Melania Participate in the Pardoning of the National Thanksgiving Turkey at the White House.
#
# Just landed in Paris, France with @FLOTUS Melania. https://t.co/knULGOQF1K
#
# Prime Minister @Netanyahu and @PresidentRuvi- on behalf of @FLOTUS Melania and myself, thank you for the invitation… https://t.co/Z5YCpaRV6t
#
# frequency: 0.8492569002123143 %

# %%
# Computing silhouette using Total Variation Distance in a K-dimensional topic space, where each document is reduced to a 
# K-vector. Note that documents are hard assigned to the topic with the highest probability. In the topic space, the distance
# from a document d to a topic i (total variation) is 1 - di, where di is the i-th component of the document vector. a(d) and
# b(d) of the silhouette formula are computed computed by sorting the document k-vector in decreasing order. Due to hard 
# assignment, 1 - d0 is the distance from the document to its same topic center, while 1 - d1 is the distance from the document
# to its closest neighbor.

from collections import defaultdict
"""
def silhouette(lda, tweet):
    kvector = [x[1] for x in sorted(lda[tweet], key=lambda tup: tup[1], reverse=True)]
    if (len(kvector) < 2):
        return 1
    neigh_dist = 1 - kvector[1]
    same_dist = 1 - kvector[0]
    return (neigh_dist - same_dist) / neigh_dist
"""
def silhouette(other, same):
    return (other - same) / max(other, same)

def buildHardClusters(lda, ltest):
    docs = [lda[tweet] for tweet in ltest if len(tweet) > 0]
    clusters = [max(doc, key=lambda tup: tup[1]) for doc in docs]
    dfTest = pd.DataFrame(columns=['Topic', 'Document'])
    dfTest['Topic'] = [c[0] for c in clusters]
    dfTest['Document'] = docs
    return dfTest

def buildCentroid(cluster):
    dic = defaultdict(float)
    for doc in cluster['Document']:
        for comp in doc:
            dic[comp[0]] += comp[1]
    return [(t, p / len(cluster)) for t, p in dic.items()]

def diff(doc1, doc2):
    d = defaultdict(float)
    for comp in doc1:
        d[comp[0]] = comp[1]
    for comp in doc2:
        d[comp[0]] -= comp[1]
    tot = 0
    for k, v in d.items():
        tot += v**2
    return np.sqrt(tot)
    
def compute_silhouette(tweet, centroids):
    same_dist = diff(tweet['Document'], centroids[tweet['Topic']]) 
    # Find nearest neighbor
    neigh_dist = 999
    for i in range(len(centroids)):
        if i == tweet['Topic']:
            continue
        dist = diff(tweet['Document'], centroids[i])
        if dist < neigh_dist:
            neigh_dist = dist
    return silhouette(neigh_dist, same_dist)

def grid_search_k(train, ltest, dictionary, start_k=2, lim=100):
    res = pd.Series(index=range(start_k, lim + 1))
    for k in range(start_k, lim + 1):
        alda = models.ldamodel.LdaModel(train, num_topics=k, id2word = dictionary, passes=20)
        dfTest = buildHardClusters(alda, ltest)
        centroids = dfTest.groupby('Topic').apply(buildCentroid)
        # Compute Average Silhouette
        tot = 0
        part_sil = dfTest.apply(compute_silhouette, args=(centroids,), axis=1)
        sil = sum(part_sil) / len(dfTest)
        print("k =", k, ",", "silhouette =", sil)
        res[k] = sil
    return res

gsk = grid_search_k(train, ltest, dictionary)
# Out:
# k = 2 , silhouette = 0.6830364421793537
# k = 3 , silhouette = 0.599893967587602
# k = 4 , silhouette = 0.6283037386167517
# k = 5 , silhouette = 0.5559448200686782
# k = 6 , silhouette = 0.6060385164063
# k = 7 , silhouette = 0.5444317785567507
# k = 8 , silhouette = 0.5744446786543627
# k = 9 , silhouette = 0.5354806539703487
# k = 10 , silhouette = 0.5825288909484534

# %%
lda.save(fname="LDAModel2017")

# %%
dfTest.to_csv("Test Sample_2017.csv")
