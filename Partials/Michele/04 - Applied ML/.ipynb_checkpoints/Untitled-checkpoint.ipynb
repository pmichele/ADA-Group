# %% [markdown]
# ## 1. A naive analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("lalonde.csv", index_col='id')
# It is unrealistic that a worker has 0 salary
df = df[df['re78'] > 0]

# %%
len(df)
# Out:
# 471

# %%
control = df[df['treat'] == 0]
treat = df[df['treat'] == 1]

# %% [markdown]
# The data is not normally distributed since it's asymmetric. It is however positively skewed as shown in the boxplot and histograms. The QQ plots show a significant deviation from normality in the right tail (and also in the left tail, but that is trivial because the salary cannot be negative). This might hint to a power law since it is rare that workers have very high salaries but not so rare.

# %%
def boxplots(attr):
    ax = df[['treat', attr]].boxplot(by='treat', showmeans=True)
    ttl = ax.title
    ttl.set_position([.5, 1.1])

boxplots('re78')

# %%
treat['re78'].hist(bins=30)

# %%
control['re78'].hist(bins=20)

# %%
stats.probplot(treat['re78'], dist="norm", plot=matplotlib.pyplot)
plt.show()

# %%
stats.probplot(control['re78'], dist="norm", plot=matplotlib.pyplot)
plt.show()

# %%
control[['re78']].describe()
# Out:
#                re78
# count    331.000000
# mean    9051.990391
# std     7087.340468
# min       31.032260
# 25%     2978.358000
# 50%     7310.313000
# 75%    14131.500000
# max    25564.670000

# %%
treat[['re78']].describe()
# Out:
#                re78
# count    140.000000
# mean    8389.939665
# std     8042.944693
# min      289.789900
# 25%     3167.353750
# 50%     6504.144500
# 75%    11017.730000
# max    60307.930000

# %% [markdown]
# By comparison, we observe that the training has been mostly effective with workers with medium wage (< 2000). Indeed, the average salary increased of around 21%, from around 930 to 1150. In a similar fashion, medium-high salaries (between 2000 and 4500) experienced a 10% increment. The treatment was less effective with higher salaries.

# %%
df[df['re78'] < 2000][['treat', 're78']].boxplot(by='treat', showmeans=True)

# %% [markdown]
# ## 2. A closer look at the data

# %%
for col in df.drop('treat', 1).columns:
    boxplots(col)

# %%
treat.drop('treat', 1).hist()
plt.tight_layout()

# %%
control.drop('treat', 1).hist()
plt.tight_layout()

# %%
def qqPlots(df):
    fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(10, 7))
    i = 0
    for col in ['age', 'educ', 're74', 're75', 're78']:
        stats.probplot(df[col], dist="norm", plot=axes[i // 3, i % 3])
        axes[i // 3, i % 3].set_ylabel(col)
        i += 1
    plt.tight_layout()
    plt.show()

qqPlots(treat)

# %%
qqPlots(control)

# %%
# to do: remove 0 components in previous charts
df.describe()
# Out:
#             treat         age        educ       black      hispan     married  \
# count  471.000000  471.000000  471.000000  471.000000  471.000000  471.000000
# mean     0.297240   26.704883   10.371550    0.369427    0.127389    0.422505
# std      0.457529    9.167470    2.546578    0.483163    0.333762    0.494483
# min      0.000000   16.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000   19.000000    9.000000    0.000000    0.000000    0.000000
# 50%      0.000000   24.000000   11.000000    0.000000    0.000000    0.000000
# 75%      1.000000   31.000000   12.000000    1.000000    0.000000    1.000000
# max      1.000000   53.000000   18.000000    1.000000    1.000000    1.000000
#
#          nodegree          re74          re75          re78
# count  471.000000    471.000000    471.000000    471.000000
# mean     0.622081   4951.429966   2430.413375   8855.202489
# std      0.485383   6798.473652   3488.193489   7381.823498
# min      0.000000      0.000000      0.000000     31.032260
# 25%      0.000000      0.000000      0.000000   3040.647500
# 50%      1.000000   1291.468000    902.322600   7215.739000
# 75%      1.000000   8332.556000   3614.101500  12909.895000
# max      1.000000  35040.070000  25142.240000  60307.930000
