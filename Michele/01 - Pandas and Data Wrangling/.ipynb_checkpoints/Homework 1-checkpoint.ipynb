# %% [markdown]
# # Table of Contents
#  <p><div class="lev1"><a href="#Task-1.-Compiling-Ebola-Data"><span class="toc-item-num">Task 1.&nbsp;&nbsp;</span>Compiling Ebola Data</a></div>
#  <div class="lev1"><a href="#Task-2.-RNA-Sequences"><span class="toc-item-num">Task 2.&nbsp;&nbsp;</span>RNA Sequences</a></div>
#  <div class="lev1"><a href="#Task-3.-Class-War-in-Titanic"><span class="toc-item-num">Task 3.&nbsp;&nbsp;</span>Class War in Titanic</a></div></p>

# %%
DATA_FOLDER = 'Data' # Use the data folder provided in Tutorial 02 - Intro to Pandas.

# %% [markdown]
# ## Task 1. Compiling Ebola Data
#
# The `DATA_FOLDER/ebola` folder contains summarized reports of Ebola cases from three countries (Guinea, Liberia and Sierra Leone) during the recent outbreak of the disease in West Africa. For each country, there are daily reports that contain various information about the outbreak in several cities in each country.
#
# Use pandas to import these data files into a single `Dataframe`.
# Using this `DataFrame`, calculate for *each country*, the *daily average per month* of *new cases* and *deaths*.
# Make sure you handle all the different expressions for *new cases* and *deaths* that are used in the reports.

# %%
import pandas as pd
import glob as glob
import datetime as dt

def read_country(country):
    files = glob.glob(DATA_FOLDER + "/ebola/" + country + "/*.csv")
    df = pd.concat((pd.read_csv(file) for file in files))
    df['Country'] = country
    return df.fillna(0)

def read_countries():
    df = read_country("guinea_data")
    df = df.append(read_country("sl_data"))
    df = df.append(read_country("liberia_data"))
    return df


def normalize(df):
    df['Date'].fillna(df['date'], inplace=True)
    df['Month'] = df['Date'].map(getMonth)
    df['Day'] = df['Date'].map(getDay)
    df['Description'].fillna(df['Variable'], inplace=True)
    df['Description'].fillna(df['variable'], inplace=True)
    df['Totals'].fillna(df['National'], inplace=True)
    del df['Date']
    del df['date']
    del df['Variable']
    del df['variable']
    del df['National']
    
def getMonth(date):
    if ('/' in date):
        try :
            d = dt.datetime.strptime(date, "%m/%d/%Y")
        except ValueError:
            d = dt.datetime.strptime(date, "%m/%d/%y")
    else: d = dt.datetime.strptime(date, "%Y-%m-%d")
    return d.month

def getDay(date):
    if ('/' in date):
        try :
            d = dt.datetime.strptime(date, "%m/%d/%Y")
        except ValueError:
            d = dt.datetime.strptime(date, "%m/%d/%y")
    else: d = dt.datetime.strptime(date, "%Y-%m-%d")
    return d.day


def compute_means(tots):
    tots = tots.astype(float)
    return tots.groupby(['Month'])['Totals'].mean()

def guinea_death_means(guin):
    print("Average daily deaths per month")
    guinTots = guin[(guin['Description'] == "New deaths registered today")
                   | (guin['Description'] == "New deaths registered")][['Totals', 'Month']]
    return compute_means(guinTots)
    
def guinea_nc_means(guin):    
    print("Average daily new cases per month")
    guinTots = guin[guin['Description'] == "Total new cases registered so far"][['Totals', 'Month']]
    return compute_means(guinTots)

def liberia_death_means(lib):
    print("Average daily deaths per month")
    lib = lib[lib['Month'] < 12]
    libTots = lib[lib['Description'] == "Newly reported deaths"][['Totals', 'Month']]
    return compute_means(libTots)

def liberia_nc_means(lib):   
    print("Average daily new cases per month")
    lib = lib[lib['Month'] < 12]
    libTots = lib[(lib['Description'] == "New Case/s (Suspected)")
                 | (lib['Description'] == "New Case/s (Probable)")
                 | (lib['Description'] == "New case/s (confirmed)")][['Totals', 'Month']]
    return compute_means(libTots) * 3
    
def sl_death_means(sl):
    return 0

def sl_nc_means(sl):   
    print("Average daily new cases per month")
    slTots = sl[(sl['Description'] == "new_suspected")
                 | (sl['Description'] == "new_probable")
                 | (sl['Description'] == "new_confirmed")][['Totals', 'Month']]
    return compute_means(slTots) * 3


df = read_countries()

# check that the sum of the columns is correct
# What if the variables are different?
normalize(df)
print("1. Guinea")
guin = df[df['Country'] == "guinea_data"]
print(guinea_death_means(guin), "\n")
print(guinea_nc_means(guin), "\n")
print("2. Liberia")
lib = df[df['Country'] == "liberia_data"]
print(liberia_death_means(lib), "\n")
print(liberia_nc_means(lib), "\n")
print("3. Sierra Leone")
sl = df[df['Country'] == "sl_data"]
#sl_death_means(sl)
print(sl_nc_means(sl))
# Out:
ola/liberia_data\\2014-10-11-v149.csv', 'Data/ebola/liberia_data\\2014-10-12-v150.csv', 'Data/ebola/liberia_data\\2014-10-13-v151.csv', 'Data/ebola/liberia_data\\2014-10-16-v154.csv', 'Data/ebola/liberia_data\\2014-10-17-v155.csv', 'Data/ebola/liberia_data\\2014-10-18-v156.csv', 'Data/ebola/liberia_data\\2014-10-19-v157.csv', 'Data/ebola/liberia_data\\2014-10-20-v158.csv', 'Data/ebola/liberia_data\\2014-10-21-v159.csv', 'Data/ebola/liberia_data\\2014-10-22-v160.csv', 'Data/ebola/liberia_data\\2014-10-23-v161.csv', 'Data/ebola/liberia_data\\2014-10-24-v162.csv', 'Data/ebola/liberia_data\\2014-10-25-v163.csv', 'Data/ebola/liberia_data\\2014-10-28-v166.csv', 'Data/ebola/liberia_data\\2014-10-29-v167.csv', 'Data/ebola/liberia_data\\2014-10-30-v168.csv', 'Data/ebola/liberia_data\\2014-10-31-v169.csv', 'Data/ebola/liberia_data\\2014-11-02-v171.csv', 'Data/ebola/liberia_data\\2014-11-04-v173.csv', 'Data/ebola/liberia_data\\2014-11-08-v177.csv', 'Data/ebola/liberia_data\\2014-11-14-v183.csv', 'Data/ebola/liberia_data\\2014-11-15-v184.csv', 'Data/ebola/liberia_data\\2014-11-19-v188.csv', 'Data/ebola/liberia_data\\2014-11-20-v189.csv', 'Data/ebola/liberia_data\\2014-11-21-v190.csv', 'Data/ebola/liberia_data\\2014-11-23-v192.csv', 'Data/ebola/liberia_data\\2014-11-24-v193.csv', 'Data/ebola/liberia_data\\2014-11-26.csv', 'Data/ebola/liberia_data\\2014-11-27.c ...
# 1. Guinea
# Average daily deaths per month
# Month
# 8.0      3.4000
# 9.0      3.5625
# 10.0    15.0000
# Name: Totals, dtype: float64
#
# Average daily new cases per month
# Month
# 8.0     25.800
# 9.0     19.625
# 10.0    34.000
# Name: Totals, dtype: float64
#
# 2. Liberia
# Average daily deaths per month
# Month
# 6.0      2.000000
# 7.0      4.272727
# 8.0     23.222222
# 9.0     36.041667
# 10.0    28.040000
# 11.0    13.466667
# Name: Totals, dtype: float64
#
# Average daily new cases per month
# Month
# 6.0      5.714286
# 7.0      8.545455
# 8.0     37.222222
# 9.0     63.833333
# 10.0    45.560000
# 11.0    26.466667
# Name: Totals, dtype: float64
#
# 3. Sierra Leone
# Average daily new cases per month
# Month
# 8.0     25.150000
# 9.0     40.689655
# 10.0    70.928571
# 11.0    75.238095
# 12.0    41.000000
# Name: Totals, dtype: float64

# %% [markdown]
# ## Task 2. RNA Sequences
#
# In the `DATA_FOLDER/microbiome` subdirectory, there are 9 spreadsheets of microbiome data that was acquired from high-throughput RNA sequencing procedures, along with a 10<sup>th</sup> file that describes the content of each.
#
# Use pandas to import the first 9 spreadsheets into a single `DataFrame`.
# Then, add the metadata information from the 10<sup>th</sup> spreadsheet as columns in the combined `DataFrame`.
# Make sure that the final `DataFrame` has a unique index and all the `NaN` values have been replaced by the tag `unknown`.

# %%
import os
import glob as glob
import pandas as pd

def read_files():  
    files = glob.glob(DATA_FOLDER + "/microbiome/MID*.xls")
    meta = pd.read_excel(DATA_FOLDER + "/microbiome/metadata.xls")
    df = pd.DataFrame()
    df['BARCODE'] = None
    i = 0
    for file in files:
        df = df.append(pd.read_excel(file, header=None))
        df.fillna(meta.iloc[i], inplace = True)
        i += 1
    return df.fillna("unknown")

read_files()
# Out:
# C:\Users\Michele\Anaconda3\lib\site-packages\pandas\core\indexes\api.py:77: RuntimeWarning: '>' not supported between instances of 'int' and 'str', sort order is undefined for incomparable objects
#   result = result.union(other)
#    BARCODE                                                  0      1
# 0     MID1  Archaea "Crenarchaeota" Thermoprotei Desulfuro...    7.0
# 1     MID1  Archaea "Crenarchaeota" Thermoprotei Desulfuro...    2.0
# 2     MID1  Archaea "Crenarchaeota" Thermoprotei Sulfoloba...    3.0
# 3     MID1  Archaea "Crenarchaeota" Thermoprotei Thermopro...    3.0
# 4     MID1  Archaea "Euryarchaeota" "Methanomicrobia" Meth...    7.0
# 5     MID1  Archaea "Euryarchaeota" "Methanomicrobia" Meth...    1.0
# 6     MID1  Archaea "Euryarchaeota" "Methanomicrobia" Meth...    1.0
# 7     MID1  Archaea "Euryarchaeota" Archaeoglobi Archaeogl...    1.0
# 8     MID1  Archaea "Euryarchaeota" Archaeoglobi Archaeogl...    1.0
# 9     MID1  Archaea "Euryarchaeota" Halobacteria Halobacte...    1.0
# 10    MID1  Archaea "Euryarchaeota" Halobacteria Halobacte...    4.0
# 11    MID1  Archaea "Euryarchaeota" Halobacteria Halobacte...    1.0
# 12    MID1  Archaea "Euryarchaeota" Halobacteria Halobacte...    2.0
# 13    MID1  Archaea "Euryarchaeota" Halobacteria Halobacte...    4.0
# 14    MID1  Archaea "Euryarchaeota" Methanococci Methanoco...    1.0
# 15    MID1  Archaea "Euryarchaeota" Methanopyri Methanopyr...   12.0
# 16    MID1  Archaea "Euryarchaeota" Thermoplasmata Thermop...    2.0
# 17    MID1  Bacteria "Actinobacteria" Actinobacteria Actin...    2.0
# 18    MID1  Bacteria "Actinobacteria" Actinobacteria Actin...    1.0
# 19    MID1  Bacteria "Actinobacteria" Actinobacteria Actin...    1.0
# 20    MID1  Bacteria "Actinobacteria" Actinobacteria Actin...    1.0
# 21    MID1  Bacteria "Actinobacteria" Actinobacteria Actin...    2.0
# 22    MID1  Bacteria "Actinobacteria" Actinobacteria Actin...   53.0
# 23    MID1  Bacteria "Actinobacteria" Actinobacteria Actin...    1.0
# 24    MID1  Bacteria "Actinobacteria" Actinobacteria Actin...    2.0
# 25    MID1  Bacteria "Actinobacteria" Actinobacteria Actin...    3.0
# 26    MID1  Bacteria "Actinobacteria" Actinobacteria Actin...    1.0
# 27    MID1  Bacteria "Actinobacteria" Actinobacteria Actin...   99.0
# 28    MID1  Bacteria "Actinobacteria" Actinobacteria Actin...   17.0
# 29    MID1  Bacteria "Actinobacteria" Actinobacteria Actin...    2.0
# ..     ...                                                ...    ...
# 69    MID8  Bacteria "Firmicutes" "Clostridia" Clostridial...    6.0
# 70    MID8  Bacteria "Firmicutes" "Clostridia" Clostridial...   15.0
# 71    MID8  Bacteria "Firmicutes" "Clostridia" Clostridial...    6.0
# 72    MID8  Bacteria "Firmicutes" "Clostridia" Clostridial...    1.0
# 73    MID8  Bacteria "Firmicutes" "Clostridia" Clostridial...  616.0
# 74    MID8  Bacteria "Firmicutes" "Erysipelotrichi" "Erysi...    1.0
# 75    MID8  Bacteria "Fusobacteria" "Fusobacteria" "Fusoba...    1.0
# 76    MID8  Bacteria "Nitrospira" "Nitrospira" "Nitrospira...    2.0
# 77    MID8  Bacteria "Planctomycetes" "Planctomycetacia" P...    3.0
# 78    MID8  Bacteria "Proteobacteria" Alphaproteobacteria ...    1.0
# 79    MID8  Bacteria "Proteobacteria" Betaproteobacteria B...    1.0
# 80    MID8  Bacteria "Proteobacteria" Betaproteobacteria B...    1.0
# 81    MID8  Bacteria "Proteobacteria" Betaproteobacteria H...    3.0
# 82    MID8  Bacteria "Proteobacteria" Deltaproteobacteria ...    1.0
# 83    MID8  Bacteria "Proteobacteria" Deltaproteobacteria ...    1.0
# 84    MID8  Bacteria "Proteobacteria" Deltaproteobacteria ...    1.0
# 85    MID8  Bacteria "Proteobacteria" Deltaproteobacteria ...    2.0
# 86    MID8  Bacteria "Proteobacteria" Gammaproteobacteria ...   22.0
# 87    MID8  Bacteria "Proteobacteria" Gammaproteobacteria ...    1.0
# 88    MID8  Bacteria "Proteobacteria" Gammaproteobacteria ...    8.0
# 89    MID8  Bacteria "Proteobacteria" Gammaproteobacteria ...    1.0
# 90    MID8  Bacteria "Proteobacteria" Gammaproteobacteria ...    1.0
# 91    MID8  Bacteria "Proteobacteria" Gammaproteobacteria ...    3.0
# 92    MID8  Bacteria "Proteobacteria" Gammaproteobacteria ...    1.0
# 93    MID8  Bacteria "Proteobacteria" Gammaproteobacteria ...    3.0
# 94    MID8  Bacteria "Thermodesulfobacteria" Thermodesulfo...    1.0
# 95    MID8  Bacteria "Thermotogae" Thermotogae Thermotogal...    4.0
# 96    MID8  Bacteria "Thermotogae" Thermotogae Thermotogal...    2.0
# 97    MID8  Bacteria Cyanobacteria Cyanobacteria  Chloropl...    1.0
# 98    MID8  Bacteria Cyanobacteria Cyanobacteria  Chloropl...    4.0
#
# [2115 rows x 3 columns]

# %% [markdown]
# ## Task 3. Class War in Titanic
#
# Use pandas to import the data file `Data/titanic.xls`. It contains data on all the passengers that travelled on the Titanic.

# %%
from IPython.core.display import HTML
HTML(filename=DATA_FOLDER+'/titanic.html')
# Out:
# <hr><h2>Data frame:titanic3</h2>1309 observations and 14 variables, maximum # NAs:1188<hr>
# <TABLE BORDER>
# <tr><td>Name</td><td>Labels</td><td>Units</td><td>Levels</td><td>Storage</td><td>NAs</td></tr>
# <tr><td>pclass</td><td></td><td></td><td><a href="#pclass"><div align=right>  3</div></a></td><td>integer</td><td><div align=right>   0</div></td></tr>
# <tr><td>survived</td><td>Survived</td><td></td><td><div align=right></div></td><td>double</td><td><div align=right>   0</div></td></tr>
# <tr><td>name</td><td>Name</td><td></td><td><div align=right></div></td><td>character</td><td><div align=right>   0</div></td></tr>
# <tr><td>sex</td><td></td><td></td><td><a href="#sex"><div align=right>  2</div></a></td><td>integer</td><td><div align=right>   0</div></td></tr>
# <tr><td>age</td><td>Age</td><td>Year</td><td><div align=right></div></td><td>double</td><td><div align=right> 263</div></td></tr>
# <tr><td>sibsp</td><td>Number of Siblings/Spouses Aboard</td><td></td><td><div align=right></div></td><td>double</td><td><div align=right>   0</div></td></tr>
# <tr><td>parch</td><td>Number of Parents/Children Aboard</td><td></td><td><div align=right></div></td><td>double</td><td><div align=right>   0</div></td></tr>
# <tr><td>ticket</td><td>Ticket Number</td><td></td><td><div align=right></div></td><td>character</td><td><div align=right>   0</div></td></tr>
# <tr><td>fare</td><td>Passenger Fare</td><td>British Pound (\243)</td><td><div align=right></div></td><td>double</td><td><div align=right>   1</div></td></tr>
# <tr><td>cabin</td><td></td><td></td><td><a href="#cabin"><div align=right>187</div></a></td><td>integer</td><td><div align=right>   0</div></td></tr>
# <tr><td>embarked</td><td></td><td></td><td><a href="#embarked"><div align=right>  3</div></a></td><td>integer</td><td><div align=right>   2</div></td></tr>
# <tr><td>boat</td><td></td><td></td><td><a href="#boat"><div align=right> 28</div></a></td><td>integer</td><td><div align=right>   0</div></td></tr>
# <tr><td>body</td><td>Body Identification Number</td><td></td><td><div align=right></div></td><td>double</td><td><div align=right>1188</div></td></tr>
# <tr><td>home.dest</td><td>Home/Destination</td><td></td><td><div align=right></div></td><td>character</td><td><div align=right>   0</div></td></tr>
# </TABLE>
# <hr>
# <TABLE BORDER>
# <tr><td>Variable</td><td>Levels</td></tr>
# <tr><td><a name="pclass">pclass</a></td><td>1st</td></tr>
# <tr><td></td><td>2nd</td></tr>
# <tr><td></td><td>3rd</td></tr>
# <tr><td><a name="sex">sex</a></td><td>female</td></tr>
# <tr><td></td><td>male</td></tr>
# <tr><td><a name="cabin">cabin</a></td><td></td></tr>
# <tr><td></td><td>A10</td></tr>
# <tr><td></td><td>A11</td></tr>
# <tr><td></td><td>A14</td></tr>
# <tr><td></td><td>A16</td></tr>
# <tr><td></td><td>A18</td></tr>
# <tr><td></td><td>A19</td></tr>
# <tr><td></td><td>A20</td></tr>
# <tr><td></td><td>A21</td></tr>
# <tr><td></td><td>A23</td></tr>
# <tr><td></td><td>A24</td></tr>
# <tr><td></td><td>A26</td></tr>
# <tr><td></td><td>A29</td></tr>
# <tr><td></td><td>A31</td></tr>
# <tr><td></td><td>A32</td></tr>
# <tr><td></td><td>A34</td></tr>
# <tr><td></td><td>A36</td></tr>
# <tr><td></td><td>A5</td></tr>
# <tr><td></td><td>A6</td></tr>
