# %%
# Import libraries
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
r = requests.get('https://www.topuniversities.com/sites/default/files/qs-rankings-data/357051_indicators.txt')
# Extract the header
data = r.json()['data'][:200]

# %%
# There is only one table
# Stylish Academic Writing
df = pd.DataFrame(columns=['Rank', 'Country', 'Region'])
df.index.name = 'Name'
for d in data:
    index = BeautifulSoup(data[0]['uni'], 'html.parser').a.text
    df.loc[d['uni']] = [d['overall_rank'], d['location'], d['region']]
    
df
# Out:
#   File "<ipython-input-123-0188be5fd3fa>", line 7
#     df.loc[index = [d['overall_rank'], d['location'], d['region']]
#                  ^
# SyntaxError: invalid syntax

# %%
df
# Out:
#                                                    Rank         Country  \
# Name
# <div class="td-wrap"><div class="td-wrap-in"><a...    1   United States
# <div class="td-wrap"><div class="td-wrap-in"><a...    2   United States
# <div class="td-wrap"><div class="td-wrap-in"><a...    3   United States
# <div class="td-wrap"><div class="td-wrap-in"><a...    4   United States
# <div class="td-wrap"><div class="td-wrap-in"><a...    5  United Kingdom
# <div class="td-wrap"><div class="td-wrap-in"><a...    6  United Kingdom
# <div class="td-wrap"><div class="td-wrap-in"><a...    7  United Kingdom
# <div class="td-wrap"><div class="td-wrap-in"><a...    8  United Kingdom
# <div class="td-wrap"><div class="td-wrap-in"><a...    9   United States
# <div class="td-wrap"><div class="td-wrap-in"><a...   10     Switzerland
# <div class="td-wrap"><div class="td-wrap-in"><a...   11       Singapore
# <div class="td-wrap"><div class="td-wrap-in"><a...   12     Switzerland
# ...

# %%
# Out:
# {'region': 'North America', 'location': 'United States', 'overall_rank': '1', 'overall_rank_dis': '<div class="td-wrap"><div class="td-wrap-in"><div class="bg "><span class="ibg" style="width: 100%;"></span><span class="rank ">1</span></div></div></div>', 'uni': '<div class="td-wrap"><div class="td-wrap-in"><a href="/universities/massachusetts-institute-technology-mit">Massachusetts Institute of Technology (MIT) </a></div></div>', 'overall': '<div class="td-wrap"><div class="td-wrap-in">100</div></div>', 'stars': '6', '2971069': '<div class="td-wrap"><div class="td-wrap-in">100</div></div>', '2971069_rank_d': '<div class="td-wrap"><div class="td-wrap-in"><div class="bg "><span class="ibg" style="width: 100%;"></span><span class="rank ">6</span></div></div></div>', '2971070': '<div class="td-wrap"><div class="td-wrap-in">99.9</div></div>', '2971070_rank_d': '<div class="td-wrap"><div class="td-wrap-in"><div class="bg "><span class="ibg" style="width: 99.9%;"></span><span class="rank "
# ...
